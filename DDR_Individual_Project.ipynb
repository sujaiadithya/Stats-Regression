# %% [markdown]
# # DDR Individual Project - Sujai Adithya Muralidharan
# ## Part 1: Scraping and Saving HTML Content
#
# Importing the necessary libraries:

# %%
from bs4 import BeautifulSoup
import requests
import time
import os
import re

# %% [markdown]
# ### 1. Identify the Target:
# Start with navigating to the “free” section on the Craigslist San Francisco Bay Area site (https://sfbay.craigslist.org/search/zip Links to an external site.).
#
# This page lists items that people are giving away for free.

# %% [markdown]
# ### 2. Interact with the Page-Sorting:
#
# Initially, the listings might be sorted by “newest” first.  Try changing the sorting order to “oldest” first by interacting with the page’s UI.
#
# Observe any changes in the URL after you change the sorting order back and forth.

# %% [markdown]
# #### Can you trigger the sorting change directly by modifying only the URL in your browser’s address bar?  If so, how?
# In the original link, if we add 'sort=dateoldest', then we can sort it by oldest first. This is shown as follows: https://sfbay.craigslist.org/search/zip?sort=dateoldest#search=1~gallery~0~0
#
# If we set 'sort=date', then we sort it by newest first: https://sfbay.craigslist.org/search/zip?sort=date#search=1~gallery~0~0

# %% [markdown]
# #### Explain what type of request is made when you change the sort order (GET or POST).
# When we change the sort order in the URL, we are making a GET request. We are making this request to retrieve data from the server based on the URL parameters. This is not a POST request because it does not involve sending any data to the server, like submitting login credentials or filling out a form. We are just displaying the existing data in a different way by tweaking the URL.

# %% [markdown]
# #### What is the variable in the URL associated with sorting?
# The variable associated with sorting in this case is 'sort'. When we set the sort variable to 'dateoldest' we sort it by oldest first, and when we set it to 'date' we sort it by newest first.

# %% [markdown]
# ### 3. Interact with the Page-Pagination:
# Craigslist paginates listings, typically displaying a limited number of items per page (120 for me).
#
# #### Navigate to the second and third pages of results and observe the changes in the URL.
#
# Page 1: https://sfbay.craigslist.org/search/zip#search=1~gallery~0~0
#
# Page 2: https://sfbay.craigslist.org/search/zip#search=1~gallery~1~0
#
# Page 3: https://sfbay.craigslist.org/search/zip#search=1~gallery~2~0

# %% [markdown]
# #### Exploration Task: Determine how to move between pages by only changing the URL.  What part of the URL changes as you navigate through different pages? This task will help you understand how pagination works on Craigslist and how you can programmatically access different pages of listings.
#
# In the link, if we change the number after 'gallery~' to the desired page number subtracted by 1, we can move between pages by only changing the URL. We subtract by 1 because the first page is indexed as 0.

# %% [markdown]
# #### Identify the variable associated with page changes.  How does altering this variable in the URL affect the page you’re viewing? Explain.
#
# The variable associated with page changes here is the number after 'gallery~'. If we alter this variable in the URL, we can choose which page we want to view. Since the first page is indexed as zero, we need to set this variable to a number that is one less than our desired page. For example, if we want to see page 5, we set this number to 4. This sends a GET request to display page 4 in the browser.

# %% [markdown]
# ### 4. Fetch Listing URLs:
# Use `requests` to access the first page of the “free” section, ordered “newest” first.
#
# Deploy `BeautifulSoup` to parse the HTML content.

# %%
headers = {'User-Agent' : 'Mozilla/5.0'}

url = 'https://sfbay.craigslist.org/search/zip?sort=date#search=1~gallery~0~0'
page = requests.get(url, headers)

soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:title"/>
#   <meta content="SF bay area free stuff - craigslist" name="description"/>
#   <meta content="SF bay area free stuff - craigslist" property="og:description"/>
#   <meta content="https://sfbay.craigslist.org/search/zip" property="og:url"/>
#   <title>
#    SF bay area free stuff - craigslist
#   </title>
#   <link href="https://sfbay.craigslist.org/search/zip" rel="canonical"/>
#   <link href="https://sfbay.craigslist.org/search/zip" hreflang="x-default" rel="alternate"/>
#   <link href="/favicon.ico" id="favicon" rel="icon">
#    <script id="ld_searchpage_data" type="application/ld+json">
#     {"breadcrumb":{"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"name":"sfbay.craigslist.org","item":"https://sfbay.craigslist.org","@type":"ListItem","position":1},{"@type":"ListItem","position":2,"item":"https://sfbay.craigslist.org/search/sss","name":"for sale"},{"@type":"ListItem","position":3,"name":"free stuff","item":"https://sfbay.craigslist.org/search/zip"}]},"@type":"SearchResultsPage","@context":"https://schema.org","description":"Free Stuff in SF Bay Area"}
#    </script>
#    <script id="ld_searchpage_results" type="application/ld+json">
#     {"@type":"ItemList","@context":"https://schema.org","itemListElement":[]}
#    </script>
#    <style>
#     body {
#             font-family: sans-serif;
#         }
#
#         #no-js {
#             position: fixed;
#             z-index: 100000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             overflow:auto;
#             margin: 0;
#             background: transparent;
#         }
#
#         #no-js h1 {
#             margin: 0;
#             padding: .5em;
#             color: #00E;
#             background-color: #cccccc;
#         }
#
#         #no-js  p {
#             margin: 1em;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .unrecoverable #curtain .content,
#         .unsupported-browser #curtain .content {
#             display: block;
#             align-items: start;
#         }
#
#         #curtain h1 {
#             margin: 0;
#             padding: .5em;
#             background-color: #cccccc;
#         }
#
#         #curtain  p {
#             margin: 1em;
#             color: black;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#
#         .unrecoverable #curtain .text.unrecoverable {
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#    </style>
#    <style>
#     body {
#             margin: 0;
#             border: 0;
#             padding: 0;
#         }
#
#         ol.cl-static-search-results, .cl-static-header {
#             display:none;
#         }
#
#         .no-js ol.cl-static-search-results, .no-js .cl-static-header {
#             display:block;
#         }
#    </style>
#   </link>
#  </head>
#  <body class="no-js search">
#   <div class="cl-content">
#    <main>
#    </main>
#   </div>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text message" id="curtainText">
#     </div>
#     <div class="text unrecoverable">
#      <p>
#       <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#        refresh the page.
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script>
#    (function() {
#             try {
#                 window.onpageshow = function(event) {
#                     if (event.persisted && cl.upTime()>1000 && /iPhone/.test(navigator.userAgent)) {
#                         window.location.reload();
#                     }
#                 };
#
#                 window.addEventListener('DOMContentLoaded', function() {
#                     document.body.classList.remove('no-js');
#                 });
#                 document.body.classList.remove('no-js');
#             } catch(e) {
#                 console.log(e);
#             }
#         })();
#   </script>
#   <script crossorigin="anonymous" src="https://www.craigslist.org/static/www/baa6cf7b7135bef8e3098858037bf9d742326367.js">
#   </script>
#   <script>
#    window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'search',
#              {
# 'areaAbbrev': "sfo",
# 'areaCoords': ["37.500000","-122.250000"],
# 'areaId': "1",
# 'areaName': "SF bay area",
# 'defaultLocale': "en_US",
# 'initialCategoryAbbr': "zip",
# 'location': {"areaId":1,"radius":3,"lon":-122.268,"postal":"94070","url":"sfbay.craigslist.org","region":"CA","city":"San Carlos","country":"US","lat":37.495},
# 'nearbyAreas': [{"host":"stockton","name":"stockton"},{"host":"monterey","name":"monterey"},{"host":"modesto","name":"modesto"},{"host":"sacramento","name":"sacramento"},{"host":"merced","name":"merced"},{"name":"gold country","host":"goldcountry"},{"host":"yubasutter","name":"yuba-sutter"},{"name":"mendocino co","host":"mendocino"},{"host":"fresno","name":"fresno"},{"host":"chico","name":"chico"},{"host":"hanford","name":"hanford"},{"host":"slo","name":"san luis obispo"},{"name":"visalia-tulare","host":"visalia"},{"name":"reno","host":"reno"},{"host":"santamaria","name":"santa maria"},{"name":"redding","host":"redding"},{"name":"susanville","host":"susanville"},{"name":"bakersfield","host":"bakersfield"}],
# 'seoLinks': 0,
# 'subareas': [{"abbr":"sfc","name":"san francisco","id":1},{"name":"south bay","id":2,"abbr":"sby"},{"abbr":"eby","name":"east bay","id":3},{"name":"peninsula","id":4,"abbr":"pen"},{"name":"north bay","id":5,"abbr":"nby"},{"abbr":"scz","id":6,"name":"santa cruz"}],
# 'whereAmI': {"subareaId":0,"area":{"lon":"-122.250000","name":"SF bay area","id":1,"region":"CA","subareas":[{"description":"east bay area","abbr":"eby","id":3,"lon":"-122.097694","name":"east bay","lat":"37.816622"},{"lat":"38.213112","lon":"-122.552650","name":"north bay","id":5,"abbr":"nby","description":"north bay / marin"},{"lat":"37.513420","lon":"-122.237935","name":"peninsula","id":4,"abbr":"pen","description":"peninsula"},{"description":"city of san francisco","abbr":"sfc","id":1,"name":"san francisco","lon":"-122.413431","lat":"37.774419"},{"lat":"36.981202","lon":"-121.961466","name":"santa cruz","id":6,"abbr":"scz","description":"santa cruz co"},{"lat":"37.331272","description":"south bay area","abbr":"sby","id":2,"lon":"-121.925176","name":"south bay"}],"abbr":"sfo","description":"SF bay area","lat":"37.500000","hostname":"sfbay","country":"US"},"nearbyAreas":[{"lat":"39.728600","hostname":"chico","country":"US","region":"CA","subareas":[],"abbr":"chc","description":"chico, CA","lon":"-121.835999","name":"chico","id":187},{"description":"fresno / madera","subareas":[],"abbr":"fre","region":"CA","id":43,"lon":"-119.771004","name":"fresno","country":"US","hostname":"fresno","lat":"36.747799"},{"hostname":"goldcountry","country":"US","lat":"38.732498","abbr":"gld","subareas":[],"description":"gold country","region":"CA","lon":"-120.801003","name":"gold country","id":373},{"country":"US","hostname":"hanford","lat":"36.327400","description":"hanford-corcoran","subareas":[],"abbr":"hnf","region":"CA","id":709,"name":"hanford","lon":"-119.646004"},{"country":"US","hostname":"mendocino","lat":"39.363098","description":"mendocino county","abbr":"mdo","subareas":[],"region":"CA","id":454,"lon":"-123.430000","name":"mendocino co"},{"lon":"-120.482002","name":"merced","id":285,"subareas":[],"abbr":"mer","description":"merced, CA","region":"CA","hostname":"merced","country":"US","lat":"37.302200"},{"subareas":[],"abbr":"mod","description":"modesto, CA","region":"CA","name":"modesto","lon":"-120.996002","id":96,"hostname":"modesto","country":"US","lat":"37.639198"},{"lat":"36.600300","hostname":"monterey","country":"US","region":"CA","abbr":"mtb","subareas":[],"description":"monterey bay","name":"monterey","lon":"-121.893997","id":102},{"lat":"40.586700","country":"US","hostname":"redding","id":188,"name":"redding","lon":"-122.390999","region":"CA","description":"redding, CA","subareas":[],"abbr":"rdd"},{"id":92,"name":"reno","lon":"-119.813004","region":"NV","description":"reno / tahoe","abbr":"rno","subareas":[],"lat":"39.529701","country":"US","hostname":"reno"},{"hostname":"sacramento","country":"US","lat":"38.581699","abbr":"sac","subareas":[],"description":"sacramento","region":"CA","lon":"-121.492996","name":"sacramento","id":12},{"description":"san luis obispo","abbr":"slo","subareas":[],"region":"CA","id":191,"name":"san luis obispo","lon":"-120.658997","country":"US","hostname":"slo","lat":"35.282799"},{"name":"santa maria","lon":"-120.433296","id":710,"region":"CA","abbr":"smx","subareas":[],"description":"santa maria, CA","lat":"34.963799","hostname":"santamaria","country":"US"},{"description":"stockton, CA","abbr":"stk","subareas":[],"region":"CA","id":97,"name":"stockton","lon":"-121.290001","country":"US","hostname":"stockton","lat":"37.957802"},{"hostname":"susanville","country":"US","lat":"40.416302","name":"susanville","lon":"-120.653000","id":707,"subareas":[],"abbr":"ssn","description":"susanville, CA","region":"CA"},{"abbr":"vis","subareas":[],"description":"visalia-tulare","region":"CA","name":"visalia-tulare","lon":"-119.291000","id":346,"hostname":"visalia","country":"US","lat":"36.330299"},{"region":"CA","abbr":"ybs","subareas":[],"description":"yuba-sutter, CA","name":"yuba-sutter","lon":"-121.647003","id":456,"lat":"39.144402","hostname":"yubasutter","country":"US"}],"searchLocation":0}
# },
#              0
#          );
#   </script>
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <script>
#    window.cl.specialCurtainMessages = {
#             unsupportedBrowser: [
#                 "We've detected you are using a browser that is missing critical features.",
#                 "Please visit craigslist from a modern browser."
#             ],
#             unrecoverableError: [
#                 "There was an error loading the page."
#             ]
#         };
#   </script>
#   <div class="cl-static-header">
#    <a href="/">
#     craigslist
#    </a>
#    <h1>
#     Free Stuff in SF Bay Area
#    </h1>
#   </div>
#   <ol class="cl-static-search-results">
#    <li class="cl-static-hub-links">
#     <div>
#      see also
#     </div>
#    </li>
#    <li class="cl-static-search-result" title="Free Laundry Promotion">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-laundry-promotion/7715548665.html">
#      <div class="title">
#       Free Laundry Promotion
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Palo Alto
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE outdoor Standing basketball hoop">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/saratoga-free-outdoor-standing/7715547249.html">
#      <div class="title">
#       FREE outdoor Standing basketball hoop
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        saratoga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Book—Pattern and Flow">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-bookpattern-and-flow/7715547173.html">
#      <div class="title">
#       Book—Pattern and Flow
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        twin peaks / diamond hts
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Chaise lounge">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-chaise-lounge/7715546331.html">
#      <div class="title">
#       Chaise lounge
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Entertainment unit - 59&quot;x15'x23&quot;">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-entertainment-unit-59x15x23/7715546023.html">
#      <div class="title">
#       Entertainment unit - 59"x15'x23"
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland downtown
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Trampoline">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/santa-rosa-trampoline/7715545952.html">
#      <div class="title">
#       Trampoline
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        santa rosa
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free speakers and klipsch sub">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-speakers-and-klipsch-sub/7715545532.html">
#      <div class="title">
#       Free speakers and klipsch sub
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Santa Cruz
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free glass coffee table">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-glass-coffee-table/7715544591.html">
#      <div class="title">
#       Free glass coffee table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Crate &amp; Barrel Willow Sleeper Sofa">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/healdsburg-free-crate-barrel-willow/7712753370.html">
#      <div class="title">
#       Free Crate &amp; Barrel Willow Sleeper Sofa
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Healdsburg
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Books">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-books/7715542855.html">
#      <div class="title">
#       Books
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Build-your-own birdhouse">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-build-your-own-birdhouse/7715542366.html">
#      <div class="title">
#       Build-your-own birdhouse
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        nob hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Dining chairs">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-dining-chairs/7715540749.html">
#      <div class="title">
#       Dining chairs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Re-home Little Free Library">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-re-home-little-free-library/7707650061.html">
#      <div class="title">
#       Re-home Little Free Library
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose north
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Stool with back">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-stool-with-back/7715540066.html">
#      <div class="title">
#       Stool with back
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        potrero hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Used mattress - FREE">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-used-mattress-free/7713144463.html">
#      <div class="title">
#       Used mattress - FREE
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        mission district
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free loose dirt for planting">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-loose-dirt-for-planting/7712935607.html">
#      <div class="title">
#       Free loose dirt for planting
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Jose
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Meral Pick Up">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/watsonville-free-meral-pick-up/7715539437.html">
#      <div class="title">
#       Free Meral Pick Up
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        morgan hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free quality furnishings, etc">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-free-quality-furnishings-etc/7715539414.html">
#      <div class="title">
#       Free quality furnishings, etc
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free 2 king mattresses">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/petaluma-free-king-mattresses/7715535507.html">
#      <div class="title">
#       Free 2 king mattresses
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        petaluma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="IKEA MYDAL bunk bed">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/palo-alto-ikea-mydal-bunk-bed/7715535360.html">
#      <div class="title">
#       IKEA MYDAL bunk bed
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        palo alto
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Mlbor-0">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/antioch-mlbor/7715534211.html">
#      <div class="title">
#       Mlbor-0
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        pittsburg / antioch
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Classic Titles">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/saratoga-classic-titles/7706875886.html">
#      <div class="title">
#       Classic Titles
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        saratoga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Living room end table">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-living-room-end-table/7715534561.html">
#      <div class="title">
#       Living room end table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Living room coffee table">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-living-room-coffee-table/7715534049.html">
#      <div class="title">
#       Living room coffee table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Several free shipping packing storage cardboard medium size boxes box">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-several-free-shipping-packing/7715533609.html">
#      <div class="title">
#       Several free shipping packing storage cardboard medium size boxes box
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose north
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="2 outdoor chaise lounge chairs">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-outdoor-chaise-lounge-chairs/7715533359.html">
#      <div class="title">
#       2 outdoor chaise lounge chairs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Newco coffee maker">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/san-mateo-newco-coffee-maker/7715533346.html">
#      <div class="title">
#       Newco coffee maker
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        foster city
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Nursing school CD’s">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/santa-cruz-nursing-school-cds/7705769410.html">
#      <div class="title">
#       Nursing school CD’s
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Santa Cruz
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Multiple metal bed frames">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-multiple-metal-bed-frames/7715532652.html">
#      <div class="title">
#       Multiple metal bed frames
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Magazines">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/el-cerrito-magazines/7715532493.html">
#      <div class="title">
#       Magazines
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        albany / el cerrito
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Color laser multi function printer">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-color-laser-multi-function/7715531249.html">
#      <div class="title">
#       Color laser multi function printer
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="GE microwave oven">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/san-mateo-ge-microwave-oven/7715531010.html">
#      <div class="title">
#       GE microwave oven
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        foster city
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Round drum table">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-round-drum-table/7715530759.html">
#      <div class="title">
#       Round drum table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Patio sliding glass doors">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/capitola-patio-sliding-glass-doors/7715530720.html">
#      <div class="title">
#       Patio sliding glass doors
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        capitola
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Hp color laser printer with toner cartridges">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-hp-color-laser-printer-with/7715530689.html">
#      <div class="title">
#       Hp color laser printer with toner cartridges
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Saratoga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="2-window fans">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-window-fans/7715530347.html">
#      <div class="title">
#       2-window fans
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Baby Cribs-Stokke crib /Pottery Barn / double umbrella stroller! Free!">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/lafayette-baby-cribs-stokke-crib/7715530107.html">
#      <div class="title">
#       Baby Cribs-Stokke crib /Pottery Barn / double umbrella stroller! Free!
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        lafayette / orinda / moraga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE OFFICE DESKS 3X and one large conference table as shown">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/livermore-free-office-desks-3x-and-one/7713357032.html">
#      <div class="title">
#       FREE OFFICE DESKS 3X and one large conference table as shown
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        dublin / pleasanton / livermore
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="free ikea table">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-free-ikea-table/7715529892.html">
#      <div class="title">
#       free ikea table
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE TEDDY BEARS &amp; GALAXY ROSES FOR VALENTINE'S DAY TO SPREAD LOVE">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/daly-city-free-teddy-bears-galaxy-roses/7714731668.html">
#      <div class="title">
#       FREE TEDDY BEARS &amp; GALAXY ROSES FOR VALENTINE'S DAY TO SPREAD LOVE
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        ingleside / SFSU / CCSF
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free rooster">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-free-rooster/7715528405.html">
#      <div class="title">
#       Free rooster
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland west
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Sub Woofer">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/walnut-creek-sub-woofer/7715528321.html">
#      <div class="title">
#       Sub Woofer
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        walnut creek
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Landscape irrigation line">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-landscape-irrigation-line/7715528020.html">
#      <div class="title">
#       Landscape irrigation line
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="gamer chair and ikea 8 cubby shelf">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-gamer-chair-and-ikea-cubby/7715527360.html">
#      <div class="title">
#       gamer chair and ikea 8 cubby shelf
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley north / hills
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Black Office Chair">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/larkspur-free-black-office-chair/7715527208.html">
#      <div class="title">
#       Free Black Office Chair
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Larkspur
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Printer Ink &amp; Cables for Canon Pixma MX280">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/emeryville-free-printer-ink-cables-for/7715527131.html">
#      <div class="title">
#       Free Printer Ink &amp; Cables for Canon Pixma MX280
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Emeryville
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="3 drawer lateral file cabinet">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/san-anselmo-drawer-lateral-file-cabinet/7715526266.html">
#      <div class="title">
#       3 drawer lateral file cabinet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san anselmo
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free/7715525646.html">
#      <div class="title">
#       Free
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose south
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Moving ***Free*** Household Items &amp; Furniture">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-moving-free-household/7715525602.html">
#      <div class="title">
#       Moving ***Free*** Household Items &amp; Furniture
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Cabinet">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/walnut-creek-cabinet/7715525199.html">
#      <div class="title">
#       Cabinet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        walnut creek
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Trick scooter / pro scooter">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-trick-scooter-pro-scooter/7714221326.html">
#      <div class="title">
#       Trick scooter / pro scooter
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Guitar Case">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/martinez-free-guitar-case/7715524329.html">
#      <div class="title">
#       Free Guitar Case
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free outdoor table and chairs">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/petaluma-free-outdoor-table-and-chairs/7715524280.html">
#      <div class="title">
#       Free outdoor table and chairs
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Petaluma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Receiver">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/walnut-creek-receiver/7715524228.html">
#      <div class="title">
#       Receiver
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        walnut creek
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Body glove bodyboard">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/hayward-body-glove-bodyboard/7715524057.html">
#      <div class="title">
#       Body glove bodyboard
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Hayward
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Speakers">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/walnut-creek-speakers/7715520913.html">
#      <div class="title">
#       Speakers
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        walnut creek
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Assorted kitchen / eating items">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-assorted-kitchen-eating-items/7715520868.html">
#      <div class="title">
#       Assorted kitchen / eating items
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        North Oakland
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free 42 inch tv, Dark screen">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-42-inch-tv-dark-screen/7715519519.html">
#      <div class="title">
#       Free 42 inch tv, Dark screen
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        santa cruz
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="2 index card organizers">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-index-card-organizers/7714189758.html">
#      <div class="title">
#       2 index card organizers
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        ingleside / SFSU / CCSF
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="wood from tree that fell over">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/palo-alto-wood-from-tree-that-fell-over/7715518409.html">
#      <div class="title">
#       wood from tree that fell over
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        palo alto
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Curb alert-Free random- see photos">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-curb-alert-free-random-see/7715518097.html">
#      <div class="title">
#       Curb alert-Free random- see photos
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Books - A Beginners Guide to Creative Effects for Your Model Railroad">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasanton-books-beginners-guide-to/7715517490.html">
#      <div class="title">
#       Books - A Beginners Guide to Creative Effects for Your Model Railroad
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        dublin / pleasanton / livermore
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free PS4 with controllers no games">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-free-ps4-with-controllers-no/7715517244.html">
#      <div class="title">
#       Free PS4 with controllers no games
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Artificial Christmas Tree">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/hayward-artificial-christmas-tree/7715516846.html">
#      <div class="title">
#       Artificial Christmas Tree
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        hayward / castro valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="solid wood dinning room set">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-solid-wood-dinning-room-set/7714234269.html">
#      <div class="title">
#       solid wood dinning room set
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san jose south
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free wooden rounds">
#     <a href="https://sfbay.craigslist.org/scz/zip/d/aptos-free-wooden-rounds/7715514935.html">
#      <div class="title">
#       Free wooden rounds
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        aptos
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Task chair in floral print">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/alameda-task-chair-in-floral-print/7715514006.html">
#      <div class="title">
#       Task chair in floral print
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Alameda
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Treadmill">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/lafayette-treadmill/7715509943.html">
#      <div class="title">
#       Treadmill
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        lafayette / orinda / moraga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Bath light bar light">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-bath-light-bar-light/7715509713.html">
#      <div class="title">
#       Bath light bar light
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        willow glen / cambrian
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Vinyl floor tiles">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/sebastopol-vinyl-floor-tiles/7715509520.html">
#      <div class="title">
#       Vinyl floor tiles
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sebastopol
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free binders">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-binders/7715508675.html">
#      <div class="title">
#       Free binders
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="free stuff (see pics)">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-stuff-see-pics/7713265862.html">
#      <div class="title">
#       free stuff (see pics)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Russian Hill
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free outdoor candle holder">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-outdoor-candle-holder/7712855788.html">
#      <div class="title">
#       Free outdoor candle holder
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        inner richmond
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Assorted Curtain Rods">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-curtain-rods/7713944084.html">
#      <div class="title">
#       Assorted Curtain Rods
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="3Drawer CD holder storage cabinet case">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-3drawer-cd-holder-storage/7714558929.html">
#      <div class="title">
#       3Drawer CD holder storage cabinet case
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Queen aerobed air mattress with small leak">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-aerobed-air/7713089936.html">
#      <div class="title">
#       Queen aerobed air mattress with small leak
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Land line phone">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-land-line-phone/7714559986.html">
#      <div class="title">
#       Land line phone
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Couch + Sofa  FREE">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-couch-sofa-free/7715507681.html">
#      <div class="title">
#       Couch + Sofa  FREE
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Usb camera">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-usb-camera/7714559809.html">
#      <div class="title">
#       Usb camera
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Assorted Phone wires, connectors and adapters">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-phone-wires/7714688000.html">
#      <div class="title">
#       Assorted Phone wires, connectors and adapters
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Smart cat touchpad">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-smart-cat-touchpad/7714689535.html">
#      <div class="title">
#       Smart cat touchpad
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="IBM Electric Letter Font Ball">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ibm-electric-letter-font/7714743061.html">
#      <div class="title">
#       IBM Electric Letter Font Ball
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Soap Holder">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-soap-holder/7714733644.html">
#      <div class="title">
#       Soap Holder
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / seacliff
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="D-Link wireless router">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-link-wireless-router/7715506294.html">
#      <div class="title">
#       D-Link wireless router
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Toaster, pots, ice trays">
# ...
#      <div class="title">
#       Free but stained ruggable top
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Bed rail for children's bed">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/redwood-city-bed-rail-for-childrens-bed/7715214435.html">
#      <div class="title">
#       Bed rail for children's bed
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        redwood city
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Metal File cabinet 2 drawer">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/pleasanton-metal-file-cabinet-drawer/7715214277.html">
#      <div class="title">
#       Metal File cabinet 2 drawer
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        dublin / pleasanton / livermore
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free large boxes">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-large-boxes/7715213849.html">
#      <div class="title">
#       Free large boxes
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Leather Lazyboy recliner">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-leather-lazyboy-recliner/7715213622.html">
#      <div class="title">
#       Leather Lazyboy recliner
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Oakland
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Desk Lamp">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-desk-lamp/7715212074.html">
#      <div class="title">
#       Desk Lamp
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Restoration Hardware sofa">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-restoration-hardware-sofa/7715211866.html">
#      <div class="title">
#       Restoration Hardware sofa
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        lower pac hts
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="FREE Arm's Reach co-sleeper and organic mattress">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-free-arms-reach-co-sleeper-and/7715210741.html">
#      <div class="title">
#       FREE Arm's Reach co-sleeper and organic mattress
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland west
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Washer and dryer">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/los-gatos-washer-and-dryer/7715210460.html">
#      <div class="title">
#       Washer and dryer
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        los gatos
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free wood an door">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/los-gatos-free-wood-an-door/7715209887.html">
#      <div class="title">
#       Free wood an door
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Los Gatos
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="4x8 cutting matt">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/richmond-4x8-cutting-matt/7715209378.html">
#      <div class="title">
#       4x8 cutting matt
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Richmond
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="CAT HAVEN!">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/san-anselmo-cat-haven/7715208169.html">
#      <div class="title">
#       CAT HAVEN!
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san anselmo
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Large all wood desk">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-large-all-wood-desk/7715207593.html">
#      <div class="title">
#       Large all wood desk
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Claremont/Rockridge
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Rustic wheelbarrow">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-rustic-wheelbarrow/7715205056.html">
#      <div class="title">
#       Rustic wheelbarrow
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Double wide filing cabinet">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-double-wide-filing-cabinet/7711269010.html">
#      <div class="title">
#       Double wide filing cabinet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Novato
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Ivory pleather Queen bed">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-ivory-pleather-queen-bed/7715204811.html">
#      <div class="title">
#       Ivory pleather Queen bed
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Novato
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Audi wheel covers bags">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-audi-wheel-covers-bags/7708246039.html">
#      <div class="title">
#       Audi wheel covers bags
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Jose
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Radio Amateur Callbook - 1982">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-radio-amateur-callbook/7715202829.html">
#      <div class="title">
#       Radio Amateur Callbook - 1982
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        north bay / marin
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Moving Boxes">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/el-verano-free-moving-boxes/7715201118.html">
#      <div class="title">
#       Free Moving Boxes
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sonoma
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="kids Franklin goalie net">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-kids-franklin-goalie-net/7714305741.html">
#      <div class="title">
#       kids Franklin goalie net
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        marina / cow hollow
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Wooden pallet">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/san-carlos-wooden-pallet/7715198435.html">
#      <div class="title">
#       Wooden pallet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Carlos
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Air Conditioner Condenser Pad">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/campbell-air-conditioner-condenser-pad/7715197683.html">
#      <div class="title">
#       Air Conditioner Condenser Pad
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        campbell
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free tire cables">
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tire-cables/7715196374.html">
#      <div class="title">
#       Free tire cables
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Francisco
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Fire Wood (Eucalyptus tree)">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/oakland-free-fire-wood-eucalyptus-tree/7715195066.html">
#      <div class="title">
#       Free Fire Wood (Eucalyptus tree)
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        oakland rockridge / claremont
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="free store pegboard&amp;store rack misc lumber 2x4">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-store-pegboardstore/7715192199.html">
#      <div class="title">
#       free store pegboard&amp;store rack misc lumber 2x4
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        redwood city
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Glass Door Cabinet">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/richmond-glass-door-cabinet/7715191711.html">
#      <div class="title">
#       Glass Door Cabinet
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / point / annex
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Styrofoam cooler">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/san-rafael-styrofoam-cooler/7713419700.html">
#      <div class="title">
#       Styrofoam cooler
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        san rafael
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Logitek sit/stand heavy duty desktop and keyboard tray in excellent condition">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/menlo-park-logitek-sit-stand-heavy-duty/7715189639.html">
#      <div class="title">
#       Logitek sit/stand heavy duty desktop and keyboard tray in excellent condition
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Menlo Park
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="4Drawer Keyed file cabnet .">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/cupertino-4drawer-keyed-file-cabnet/7715189537.html">
#      <div class="title">
#       4Drawer Keyed file cabnet .
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Cupertino
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="basket ball  hoop">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/cupertino-basket-ball-hoop/7707732874.html">
#      <div class="title">
#       basket ball  hoop
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        Cupertino
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free Dirt">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/berkeley-free-dirt/7710471918.html">
#      <div class="title">
#       Free Dirt
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        berkeley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="free cardboard &amp; metal recycling come get it">
#     <a href="https://sfbay.craigslist.org/pen/zip/d/redwood-city-free-cardboard-metal/7715188370.html">
#      <div class="title">
#       free cardboard &amp; metal recycling come get it
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        redwood city
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title='Samsonite Luggage 12" Deep x 19" Wide x 29" Tall'>
#     <a href="https://sfbay.craigslist.org/sfc/zip/d/san-francisco-samsonite-luggage-12-deep/7708264658.html">
#      <div class="title">
#       Samsonite Luggage 12" Deep x 19" Wide x 29" Tall
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        noe valley
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Serta Perfect Sleeper Mattress">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/richmond-serta-perfect-sleeper-mattress/7715186924.html">
#      <div class="title">
#       Serta Perfect Sleeper Mattress
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        richmond / point / annex
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Large Sectional Couch">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/concord-large-sectional-couch/7711579823.html">
#      <div class="title">
#       Large Sectional Couch
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        concord / pleasant hill / martinez
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Life jackets">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/novato-life-jackets/7715185257.html">
#      <div class="title">
#       Life jackets
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        novato
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Free  Pallets">
#     <a href="https://sfbay.craigslist.org/eby/zip/d/lafayette-free-pallets/7715184389.html">
#      <div class="title">
#       Free  Pallets
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        lafayette / orinda / moraga
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="Twin Bed Box Spring By Sealy">
#     <a href="https://sfbay.craigslist.org/sby/zip/d/san-jose-twin-bed-box-spring-by-sealy/7715183951.html">
#      <div class="title">
#       Twin Bed Box Spring By Sealy
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        San Jose
#       </div>
#      </div>
#     </a>
#    </li>
#    <li class="cl-static-search-result" title="large clamps or press">
#     <a href="https://sfbay.craigslist.org/nby/zip/d/sebastopol-large-clamps-or-press/7715182862.html">
#      <div class="title">
#       large clamps or press
#      </div>
#      <div class="details">
#       <div class="price">
#        $0
#       </div>
#       <div class="location">
#        sebastopol
#       </div>
#      </div>
#     </a>
#    </li>
#   </ol>
#  </body>
# </html>

# %% [markdown]
# #### Identify the structure that holds the links to individual listing pages.  What selector do you choose to grab the link?
# The structure that holds the links to individual listing pages is the tage 'li' with the class 'cl-static-search-result'. To grab the link, we use soup.select('li.cl-static-search-result').find('a')['href'].
#
# #### Can you identify one more possible selection method to retrieve the link to the individual listing?  Explain.
# We have URLs in two parts of the the html. Both are under 'li.cl-static-search-result', however one is an anchor located inside 'div.gallery-inner' and the other is an anchor located under 'div.gallery-card'. We can specify either of them and extract the links using two methods.
#
# #### Extract the first 250 unique listing URLs and save them to a list.  Consider the pagination feature of Craigslist to navigate through pages.  Explain your strategy. Print the list to screen.
#
# Here, we are going to do the same and run a for loop to extract the links for 250 listings and saving it to a list. We are not worried about pagination because the html output when we print 'soup' is not the same as when we inspect the site in the browser. The html output that we get in the soup object contains more than 250 listings in itself, so we can directly extract them without considering pagination. The result has been printed below.

# %%
lists = []

links = soup.select('li.cl-static-search-result')

for l in links[:250]:
    link = l.find('a')['href']
    print(link)
    lists.append(link)
# Out:
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-laundry-promotion/7715548665.html
# https://sfbay.craigslist.org/sby/zip/d/saratoga-free-outdoor-standing/7715547249.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-bookpattern-and-flow/7715547173.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-chaise-lounge/7715546331.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-entertainment-unit-59x15x23/7715546023.html
# https://sfbay.craigslist.org/nby/zip/d/santa-rosa-trampoline/7715545952.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-speakers-and-klipsch-sub/7715545532.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-glass-coffee-table/7715544591.html
# https://sfbay.craigslist.org/nby/zip/d/healdsburg-free-crate-barrel-willow/7712753370.html
# https://sfbay.craigslist.org/eby/zip/d/el-cerrito-books/7715542855.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-build-your-own-birdhouse/7715542366.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-dining-chairs/7715540749.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-re-home-little-free-library/7707650061.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-stool-with-back/7715540066.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-used-mattress-free/7713144463.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-loose-dirt-for-planting/7712935607.html
# https://sfbay.craigslist.org/sby/zip/d/watsonville-free-meral-pick-up/7715539437.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-free-quality-furnishings-etc/7715539414.html
# https://sfbay.craigslist.org/nby/zip/d/petaluma-free-king-mattresses/7715535507.html
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-ikea-mydal-bunk-bed/7715535360.html
# https://sfbay.craigslist.org/eby/zip/d/antioch-mlbor/7715534211.html
# https://sfbay.craigslist.org/sby/zip/d/saratoga-classic-titles/7706875886.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-living-room-end-table/7715534561.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-living-room-coffee-table/7715534049.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-several-free-shipping-packing/7715533609.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-outdoor-chaise-lounge-chairs/7715533359.html
# https://sfbay.craigslist.org/pen/zip/d/san-mateo-newco-coffee-maker/7715533346.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-nursing-school-cds/7705769410.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-multiple-metal-bed-frames/7715532652.html
# https://sfbay.craigslist.org/eby/zip/d/el-cerrito-magazines/7715532493.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-color-laser-multi-function/7715531249.html
# https://sfbay.craigslist.org/pen/zip/d/san-mateo-ge-microwave-oven/7715531010.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-round-drum-table/7715530759.html
# https://sfbay.craigslist.org/scz/zip/d/capitola-patio-sliding-glass-doors/7715530720.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-hp-color-laser-printer-with/7715530689.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-window-fans/7715530347.html
# https://sfbay.craigslist.org/eby/zip/d/lafayette-baby-cribs-stokke-crib/7715530107.html
# https://sfbay.craigslist.org/eby/zip/d/livermore-free-office-desks-3x-and-one/7713357032.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-free-ikea-table/7715529892.html
# https://sfbay.craigslist.org/sfc/zip/d/daly-city-free-teddy-bears-galaxy-roses/7714731668.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-free-rooster/7715528405.html
# https://sfbay.craigslist.org/eby/zip/d/walnut-creek-sub-woofer/7715528321.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-landscape-irrigation-line/7715528020.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-gamer-chair-and-ikea-cubby/7715527360.html
# https://sfbay.craigslist.org/nby/zip/d/larkspur-free-black-office-chair/7715527208.html
# https://sfbay.craigslist.org/eby/zip/d/emeryville-free-printer-ink-cables-for/7715527131.html
# https://sfbay.craigslist.org/nby/zip/d/san-anselmo-drawer-lateral-file-cabinet/7715526266.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free/7715525646.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-moving-free-household/7715525602.html
# https://sfbay.craigslist.org/eby/zip/d/walnut-creek-cabinet/7715525199.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-trick-scooter-pro-scooter/7714221326.html
# https://sfbay.craigslist.org/eby/zip/d/martinez-free-guitar-case/7715524329.html
# https://sfbay.craigslist.org/nby/zip/d/petaluma-free-outdoor-table-and-chairs/7715524280.html
# https://sfbay.craigslist.org/eby/zip/d/walnut-creek-receiver/7715524228.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-body-glove-bodyboard/7715524057.html
# https://sfbay.craigslist.org/eby/zip/d/walnut-creek-speakers/7715520913.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-assorted-kitchen-eating-items/7715520868.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-42-inch-tv-dark-screen/7715519519.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-index-card-organizers/7714189758.html
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-wood-from-tree-that-fell-over/7715518409.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-curb-alert-free-random-see/7715518097.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-books-beginners-guide-to/7715517490.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-ps4-with-controllers-no/7715517244.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-artificial-christmas-tree/7715516846.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-solid-wood-dinning-room-set/7714234269.html
# https://sfbay.craigslist.org/scz/zip/d/aptos-free-wooden-rounds/7715514935.html
# https://sfbay.craigslist.org/eby/zip/d/alameda-task-chair-in-floral-print/7715514006.html
# https://sfbay.craigslist.org/eby/zip/d/lafayette-treadmill/7715509943.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-bath-light-bar-light/7715509713.html
# https://sfbay.craigslist.org/nby/zip/d/sebastopol-vinyl-floor-tiles/7715509520.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-binders/7715508675.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-stuff-see-pics/7713265862.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-outdoor-candle-holder/7712855788.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-curtain-rods/7713944084.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-3drawer-cd-holder-storage/7714558929.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-queen-aerobed-air/7713089936.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-land-line-phone/7714559986.html
# https://sfbay.craigslist.org/eby/zip/d/pleasant-hill-couch-sofa-free/7715507681.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-usb-camera/7714559809.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-assorted-phone-wires/7714688000.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-smart-cat-touchpad/7714689535.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ibm-electric-letter-font/7714743061.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-soap-holder/7714733644.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-link-wireless-router/7715506294.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-toaster-pots-ice-trays/7715505539.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-shaped-glass-desk/7715505407.html
# https://sfbay.craigslist.org/nby/zip/d/sebastopol-queen-size-comforter/7715505302.html
# https://sfbay.craigslist.org/eby/zip/d/lafayette-free-art-deco-lamp/7715504693.html
# https://sfbay.craigslist.org/eby/zip/d/alameda-square-glass-table-top/7715503848.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-metal-garden-bench/7715503792.html
# https://sfbay.craigslist.org/eby/zip/d/emeryville-free-bags-of-wood-kindling/7715503718.html
# https://sfbay.craigslist.org/nby/zip/d/sausalito-various-free-things/7710584033.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-witch-hazel/7714206761.html
# https://sfbay.craigslist.org/eby/zip/d/fairfield-free-bedroom-set/7715500343.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-pallet/7715497408.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-baby-gate-inches/7715496150.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-cat-furniture/7715495862.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-humidifier-holmes/7713160483.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-costume-paint-and-fake/7713154629.html
# https://sfbay.craigslist.org/nby/zip/d/cotati-coffee-table-and-two-end-tables/7715495491.html
# https://sfbay.craigslist.org/nby/zip/d/mill-valley-infinity-kappa-speakers-pair/7715495119.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-bookshelf-vintage-wall/7715494220.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-led-retrofit-bulbs-for-pin-cfl/7715493932.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-beige-light-brown-carpet-scraps/7715493105.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-subaru-teeeter-speakers/7715493835.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-carpet-with-flowery/7715491670.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-shaped-couch-blue/7715490338.html
# https://sfbay.craigslist.org/scz/zip/d/capitola-queen-box-spring/7715490231.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-books-games/7713360347.html
# https://sfbay.craigslist.org/eby/zip/d/san-ramon-real-leather-sofa-with/7708907086.html
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-easter-decorations/7714763829.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-bamboo-charging-station/7715484285.html
# https://sfbay.craigslist.org/nby/zip/d/windsor-free-counter-top/7712206329.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-garage-grade-free-folding-table/7715481682.html
# https://sfbay.craigslist.org/nby/zip/d/windsor-free-counter-top/7710582593.html
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-free-chair-headboard-filing/7713900033.html
# https://sfbay.craigslist.org/eby/zip/d/union-city-used-37-tires/7711667389.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-samsung-galaxy-gear-vr-oculus/7715477246.html
# https://sfbay.craigslist.org/eby/zip/d/richmond-glass-shower-doors/7715477067.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-tire-continential/7715474830.html
# https://sfbay.craigslist.org/pen/zip/d/san-carlos-subaru-crosstrek-engine-free/7715474805.html
# https://sfbay.craigslist.org/pen/zip/d/mountain-view-free-amazon-boxes/7715474218.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-queen-anne-table-175/7715472948.html
# https://sfbay.craigslist.org/nby/zip/d/sausalito-coffee-table-thick-cut-glass/7707133848.html
# https://sfbay.craigslist.org/pen/zip/d/redwood-city-wall-art-free/7715472124.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-curb-alert-free-sandbags/7715471741.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-entertainment-unit/7715471475.html
# https://sfbay.craigslist.org/pen/zip/d/redwood-city-whiteboard/7715470701.html
# https://sfbay.craigslist.org/eby/zip/d/richmond-large-sheet-of-tempered-glass/7715470479.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-box-spring-full-size/7715470127.html
# https://sfbay.craigslist.org/nby/zip/d/vallejo-twin-quilt/7715468334.html
# https://sfbay.craigslist.org/eby/zip/d/richmond-round-4-glass-for-table-top/7715468312.html
# https://sfbay.craigslist.org/scz/zip/d/hollister-hollister-arborist-woodchips/7711183528.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-wooden-cabinet/7715466412.html
# https://sfbay.craigslist.org/eby/zip/d/richmond-round-table-top-with-lazy-susan/7715466178.html
# https://sfbay.craigslist.org/eby/zip/d/martinez-free-workbench-or-desk-plus/7715453823.html
# https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-panasonic-surround/7715461356.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-sandbags/7715459120.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-foot-corrugated/7713576351.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-craps-table-for-free/7715458153.html
# https://sfbay.craigslist.org/sby/zip/d/sunnyvale-laskso-utility-fan/7715451702.html
# https://sfbay.craigslist.org/pen/zip/d/los-altos-leather-couch-no-tears/7715451413.html
# https://sfbay.craigslist.org/sby/zip/d/sunnyvale-2013-highlander-rear-area-mat/7715450519.html
# https://sfbay.craigslist.org/nby/zip/d/larkspur-vitamaster-triumph-treadmill/7711309600.html
# https://sfbay.craigslist.org/eby/zip/d/martinez-free-storage-cabinet-plus-ill/7715449942.html
# https://sfbay.craigslist.org/eby/zip/d/lafayette-free-desk-chair-with-arms/7715449570.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free/7714735168.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-construction-safety/7714717921.html
# https://sfbay.craigslist.org/pen/zip/d/menlo-park-free-fig-tree/7715447828.html
# https://sfbay.craigslist.org/eby/zip/d/martinez-free-mirror/7715447784.html
# https://sfbay.craigslist.org/nby/zip/d/windsor-grape-gondola/7715447740.html
# https://sfbay.craigslist.org/eby/zip/d/lafayette-free-desk-chair/7715447619.html
# https://sfbay.craigslist.org/eby/zip/d/richmond-crutches/7715447614.html
# https://sfbay.craigslist.org/sfc/zip/d/free-bags-of-sand-construction/7712106559.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-free-lazy-boy-sectional-couch/7715444062.html
# https://sfbay.craigslist.org/sfc/zip/d/daly-city-free-walker/7715444053.html
# https://sfbay.craigslist.org/nby/zip/d/santa-rosa-free-kitchen-sink/7709526645.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-small-sofa/7715442405.html
# https://sfbay.craigslist.org/nby/zip/d/novato-file-cabinet-oak/7715440534.html
# https://sfbay.craigslist.org/pen/zip/d/atherton-free-bucket-buddy-tool-holder/7715438964.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-wood-chips/7715436732.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-drawer-metal-filing-cabinet/7715434602.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-two-twin-box-spring/7715434405.html
# https://sfbay.craigslist.org/nby/zip/d/bolinas-free-working-record-player/7712443048.html
# https://sfbay.craigslist.org/eby/zip/d/dublin-office-furniture-desks-hutch/7715427395.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ikea-ceiling-spot-lights/7712855303.html
# https://sfbay.craigslist.org/eby/zip/d/concord-cpcu-commercial-insurance/7707638711.html
# https://sfbay.craigslist.org/scz/zip/d/scotts-valley-free-king-size-bed/7715423737.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tv-art-stand-like-new/7715423129.html
# https://sfbay.craigslist.org/nby/zip/d/san-rafael-tv-40-samsung-free/7710945210.html
# https://sfbay.craigslist.org/sby/zip/d/cupertino-half-bag-of-ice/7715418706.html
# https://sfbay.craigslist.org/nby/zip/d/healdsburg-free-circular-saw-with-case/7715416372.html
# https://sfbay.craigslist.org/sby/zip/d/cupertino-1978-toyota-celica-parts/7712891804.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-ikea-sparsam-bulbs-brand/7715416308.html
# https://sfbay.craigslist.org/eby/zip/d/castro-valley-free-concrete-decorative/7712229203.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-upright-piano/7710208630.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-office-desk/7710140691.html
# https://sfbay.craigslist.org/eby/zip/d/walnut-creek-free-275-gallon-water-totes/7715414014.html
# https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-small-microwave/7715412792.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-free-working-fridge/7715411920.html
# https://sfbay.craigslist.org/sby/zip/d/sunnyvale-free-balloon-arch/7715407430.html
# https://sfbay.craigslist.org/eby/zip/d/albany-drapes-heavy-duty/7715405474.html
# https://sfbay.craigslist.org/eby/zip/d/moraga-tv-media-stand/7709936764.html
# https://sfbay.craigslist.org/eby/zip/d/alameda-free-electronics/7714484558.html
# https://sfbay.craigslist.org/sby/zip/d/santa-clara-honda-z50-flywheels-mini/7708533912.html
# https://sfbay.craigslist.org/nby/zip/d/el-verano-free-cushions/7714703932.html
# https://sfbay.craigslist.org/nby/zip/d/windsor-gas-powered-lawn-edger/7715404283.html
# https://sfbay.craigslist.org/eby/zip/d/albany-box-of-shoes-mostly-size-75/7715403985.html
# https://sfbay.craigslist.org/eby/zip/d/danville-free-latch-hook-rug-yarn/7715403901.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-35-floppy-diskettes/7715401628.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-bed-frame/7715401432.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-woven-jute-green/7714680123.html
# https://sfbay.craigslist.org/eby/zip/d/berkeley-employee-lockers/7715400905.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-free-six-sided-picnic-table/7715399300.html
# https://sfbay.craigslist.org/eby/zip/d/fremont-large-desk-with-drawers/7707527407.html
# https://sfbay.craigslist.org/sby/zip/d/cupertino-old-iphone-docking-am-fm-radio/7715396209.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-storage-bin-for-yard-waste/7712840017.html
# https://sfbay.craigslist.org/eby/zip/d/fremont-free-sony-bravia-32-tv/7715395017.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-tv-42-inch-panasonic-th/7715394714.html
# https://sfbay.craigslist.org/sby/zip/d/cupertino-blood-pressure-monitor-leak/7715394067.html
# https://sfbay.craigslist.org/eby/zip/d/hayward-couch-with-pull-out-bed/7705495184.html
# https://sfbay.craigslist.org/pen/zip/d/san-mateo-ikea-queen-mattress/7715394295.html
# https://sfbay.craigslist.org/pen/zip/d/belmont-free-chair-with-wheels/7715393112.html
# https://sfbay.craigslist.org/pen/zip/d/el-granada-free-interior-wood-doors/7709864918.html
# https://sfbay.craigslist.org/eby/zip/d/pleasanton-free-dirt-or-soil/7715390396.html
# https://sfbay.craigslist.org/sfc/zip/d/daly-city-boxes-of-various-sizes-with/7715390300.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-shelves-and-desk/7711571686.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-music-stand/7715389485.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-large-mirror/7715387868.html
# https://sfbay.craigslist.org/nby/zip/d/petaluma-foam-insulation-board-2-thick/7715387630.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-home-made-shabby-shelves/7709809392.html
# https://sfbay.craigslist.org/eby/zip/d/pittsburg-couch-and-recliners-freeill/7714356712.html
# https://sfbay.craigslist.org/pen/zip/d/menlo-park-sofas-beige-sofa-for-free/7711928339.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-guitar-shipping-boxes/7713368522.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-antique-arm-chair/7715372780.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-clay-garden-pipe/7715369693.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-pallets-for-free/7706234024.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-free-clean-dirt-and-delivery/7715366372.html
# https://sfbay.craigslist.org/eby/zip/d/san-leandro-two-full-brand-new-full/7715365337.html
# https://sfbay.craigslist.org/nby/zip/d/santa-rosa-clay-thrower/7715365099.html
# https://sfbay.craigslist.org/pen/zip/d/san-mateo-free-recliner/7715364437.html
# https://sfbay.craigslist.org/nby/zip/d/novato-wood-salad-bowl-and-servers/7715364328.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-floor-plastic-water-proof-sheet/7715363491.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-bbq-coal-and-plastic-container/7715360612.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-maytag-stacked-washer/7715358339.html
# https://sfbay.craigslist.org/nby/zip/d/penngrove-cal-king-bed-with-frame/7710098837.html
# https://sfbay.craigslist.org/nby/zip/d/petaluma-two-chairs/7715354139.html
# https://sfbay.craigslist.org/eby/zip/d/vallejo-wooden-window-planter-box/7711894549.html
# https://sfbay.craigslist.org/scz/zip/d/santa-cruz-ikea-high-chair/7711829052.html
# https://sfbay.craigslist.org/eby/zip/d/concord-dvd/7715347533.html
# https://sfbay.craigslist.org/eby/zip/d/concord-glassware/7715347447.html
# https://sfbay.craigslist.org/eby/zip/d/concord-household-items/7715347381.html
# https://sfbay.craigslist.org/sby/zip/d/sunnyvale-queen-size-mattress-boxspring/7715343484.html
# https://sfbay.craigslist.org/pen/zip/d/palo-alto-wood-benching-tables/7715335093.html
# https://sfbay.craigslist.org/scz/zip/d/mount-hermon-curbside-alert/7715332769.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-microwave-oven-for-above/7715330009.html
# https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-ceiling-fan/7715329535.html
# https://sfbay.craigslist.org/eby/zip/d/san-leandro-free-office-chair/7715329244.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-vessel-bathroom-sink/7715324233.html
# https://sfbay.craigslist.org/pen/zip/d/burlingame-free-sectional-couch-in/7715323804.html
# https://sfbay.craigslist.org/nby/zip/d/laytonville-hospital-bed/7715314438.html
# https://sfbay.craigslist.org/sfc/zip/d/san-francisco-free-tools-airless/7710482416.html
# https://sfbay.craigslist.org/sby/zip/d/san-jose-brand-new-fluourescent-light/7715308763.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-free-brown-paper-grocery-bags/7715308197.html
# https://sfbay.craigslist.org/eby/zip/d/oakland-available-large-table-with/7711266767.html
# https://sfbay.craigslist.org/scz/zip/d/morgan-hill-free-wood-chips-clean/7715306849.html
# https://sfbay.craigslist.org/sby/zip/d/milpitas-free-stuu/7715306246.html
# https://sfbay.craigslist.org/scz/zip/d/capitola-raft-rapid-rider/7715305986.html
# https://sfbay.craigslist.org/sby/zip/d/milpitas-plywood/7715305433.html
# https://sfbay.craigslist.org/sby/zip/d/milpitas-proform-treadmill/7715302679.html

# %% [markdown]
# #### 5. Save HTML Pages:
# For each of the 250 listing URLs, use `requests` to fetch the listing page.
#
# Save each HTML content to a separate file on disk.  Use each listing’s ID to organize files in a way that makes them easily identifiable (e.g., save listing ID 7713901653 to file “7713901653.html”).

# %%
x = os.getcwd()
print(x)
# Out:
# /Users/sujaiadithya/Desktop/DDR Project

# %% [markdown]
# Saving the page content of each of the HTML link to a local directory: /Users/sujaiadithya/Desktop/DDR Project/HTML_Links. Creating a regex pattern to extract the listing ID and setting that as the .html file name. A time gap of 5 seconds is set between each response.

# %%
folder = 'HTML_Links'
regex = r'\/([0-9]+)\.html$'

for url2 in lists:
    match = re.search(regex, url2)
    if match:
        ids = match.group(1)
        page2 = requests.get(url2)
        soup2 = BeautifulSoup(page2.content, 'html.parser')
        local_folder = os.path.join(folder, f"{ids}.html")
        f = open(local_folder, 'w', encoding='utf-8')
        f.write(soup2.prettify())
        f.close()
        time.sleep(5)

# %% [markdown]
# ## Part 2: Parsing and Displaying Information from Saved HTML
#
# ### 1. Read Saved HTML Files:
# Write a script that reads each of the saved HTML files from the disk.
#
# ### 2. Extract Information:
# For each HTML file, use `BeautifulSoup` to parse the file content.
#
# Extract and print the following details:
#
# Title: The title of the listing.
#
# URL of first image (if an image exists):  The URL of the displayed image.  It can be found in the `src` attribute of `<img>`
#
# Description: The full description text of the listing.
#
# Post ID: Usually found at the bottom of the page or within the page's HTML structure.
#
# Posted Date: The date when the listing was originally posted.
#
# Last Updated Date: The date when the listing was last updated.
#
#
# Defining a function to read the saved HTML files and extract the required information as mentioned above in the question. For each required information, we are running an if loop to see if the necessary parameter exists and printing the information if it exists. In some cases, we are using .decompose() to remove certain tags under a parent class which are unnecessary to us.

# %%
def details(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".html"):
            filepath = os.path.join(directory, filename)

            print("Listing ID:", os.path.splitext(filename)[0])

            with open(filepath, 'r', encoding='utf-8') as file:
                html = file.read()

            soup5 = BeautifulSoup(html, 'html.parser')

            print("")
            title = soup5.select_one('span.postingtitletext')

            if title:
                title_full = title.find_all('span')
                full_text = ""

                for i in title_full:
                    text = i.text.strip()
                    full_text = full_text + text + " "

                print("Title:", full_text.strip())
            else:
                print("No title")

            print("")
            image = soup5.find('img')

            if image:
                img_url = image.get('src')
                print("URL of image:", img_url)
            else:
                print("No image")

            print("")
            desc = soup5.select_one("section#postingbody")

            if desc:
                qr_code = desc.select_one("p.print-qrcode-label")
                if qr_code:
                    qr_code.decompose()
                description = desc.text.strip()
                print("Description:", description)
            else:
                print("No description")

            print("")
            post = soup5.select_one("div.postinginfos")

            if post:
                bs = post.select_one("a.bestof-link")
                if bs:
                    bs.decompose()
                bs1 = post.select_one("sup")
                if bs1:
                    bs1.decompose()
                print(post.text.strip())
            else:
                print("Post ID:", os.path.splitext(filename)[0])

            print("")
            print("")
            print("")

directory = 'HTML_Links'
details(directory)
# Out:
# Listing ID: 7715526266
#
# Title: 3 drawer lateral file cabinet (san anselmo)
#
# URL of image: https://images.craigslist.org/00Q0Q_5aDc88w6ZRt_0t20CI_600x450.jpg
#
# Description: Giving away a lateral file cabinet in excellent condition. I dont have the keys, so it wont lock. other than that it works great. I am having a bunch of stuff hauled away on Saturday morning, so you need to pick it up before the haulers get there. Please dont ask if it is available, and don't tell me you want it if you are not going to show up.
#
# post id: 7715526266
#
#
#        posted:
#
#         2024-02-07 16:39
#
#
#
# Listing ID: 7714731668
#
# Title: FREE TEDDY BEARS & GALAXY ROSES FOR VALENTINE'S DAY TO SPREAD LOVE (ingleside / SFSU / CCSF)
#
# URL of image: https://images.craigslist.org/00Y0Y_8bQG1tUwXSq_0cI0oc_600x450.jpg
#
# Description: FREE TEDDY BEARS, VALENTINE PLUSH TOYS & GALAXY ROSES FOR VALENTINE'S DAY TO SPREAD LOVE on GARAGE SALE FRIDAY FEB 9, SATURDAY FEB 10 AT AND SUNDAY FEB 11 AT 249 SAGAMORE STREET IN SF FROM 10AM TO 1PM Happy Valentine's Day! See the video
#
#       https://www.youtube.com/watch?v=PmlwGG1I75M
#
# post id: 7714731668
#
#
#        posted:
#
#         2024-02-05 11:19
#
#
#
#        updated:
#
#         2024-02-07 16:48
#
#
#
# Listing ID: 7715347447
#
# Title: Glassware (walnut creek)
#
# URL of image: https://images.craigslist.org/00m0m_bIehJgXrlGv_0t20CI_600x450.jpg
#
# Description: (9" H) Candle Holder
#
#
#       (7") Small Clear Glass Plate
#
#
#
#
#       Call (925) 603-FREE [3733]
#
# post id: 7715347447
#
#
#        posted:
#
#         2024-02-07 09:00
#
#
#
# Listing ID: 7715528405
#
# Title: Free rooster (oakland west)
#
# URL of image: https://images.craigslist.org/00606_cdXKhHhRtxV_0t20CI_600x450.jpg
#
# Description: FrFree rooster! We originally thought it was a hen, but it turned out to be a rooster. Plus, I have about 15 lbs of pellet food for it. Super chill, also good around kids and other pets.
#
# post id: 7715528405
#
#
#        posted:
#
#         2024-02-07 16:48
#
#
#
# Listing ID: 7712106559
#
# Title: Free 3 Bags of sand, CONSTRUCTION MATERIALS **** (ingleside / SFSU / CCSF)
#
# URL of image: https://images.craigslist.org/01717_5Kn1i62MM9h_09G09G_600x450.jpg
#
# Description: I have 3 bags of sand that were used last week during the rain.
#
#       There are also 2 2x4, plywood and 2 roles of covering tarp(?) left from our home construction
#
#       Pls message me with a number if you are interested
#
# post id: 7712106559
#
#
#        posted:
#
#         2024-01-28 11:26
#
#
#
#        updated:
#
#         2024-02-07 12:39
#
#
#
# Listing ID: 7715472124
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715472124
#
#
#
# Listing ID: 7715545532
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715545532
#
#
#
# Listing ID: 7714735168
#
# Title: Free (San Francisco)
#
# URL of image: https://images.craigslist.org/00s0s_8pVRPBmU8tW_0ik0CI_600x450.jpg
#
# Description: Free
#
#       Text 415 756 036nine
#
# post id: 7714735168
#
#
#        posted:
#
#         2024-02-05 11:27
#
#
#
#        updated:
#
#         2024-02-07 12:48
#
#
#
# Listing ID: 7712935607
#
# Title: Free loose dirt for planting (San Jose)
#
# URL of image: https://images.craigslist.org/00e0e_bwvxaQuJUni_0CI0t2_600x450.jpg
#
# Description: Great dirt for planting while it’s raining.
#
#
#       Get as many buckets as you need. It’s already loose and easily to access from outside the side yard near street.
#
#
#       Message me with your contact and when you can come.
#
# post id: 7712935607
#
#
#        posted:
#
#         2024-01-30 23:10
#
#
#
#        updated:
#
#         2024-02-07 17:29
#
#
#
# Listing ID: 7715547173
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715547173
#
#
#
# Listing ID: 7715354139
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715354139
#
#
#
# Listing ID: 7715503718
#
# Title: Free bags of wood kindling (oakland west)
#
# URL of image: https://images.craigslist.org/00f0f_b1xlaZ5oVkS_13O0Ny_600x450.jpg
#
# Description: Raw wood scraps. Perfect for wood stove.
#
# post id: 7715503718
#
#
#        posted:
#
#         2024-02-07 15:22
#
#
#
# Listing ID: 7715394714
#
# Title: Free TV 42-inch Panasonic TH-42PX20 (dublin / pleasanton / livermore)
#
# URL of image: https://images.craigslist.org/00i0i_6XFzOKeU2hp_11I0FL_600x450.jpg
#
# Description: In good condition.
#
#       It can be used with Amazon TV Fire stick to function it as a smart TV
#
#       Come with wall mount and bolts
#
#       It's a heavy TV so make sure you have support when pick it up
#
#
#       First come first serve
#
# post id: 7715394714
#
#
#        posted:
#
#         2024-02-07 10:40
#
#
#
# Listing ID: 7715395017
#
# Title: Free Sony Bravia 32" TV (fremont / union city / newark)
#
# URL of image: https://images.craigslist.org/00z0z_28NnLGJJw5U_0pO0jm_600x450.jpg
#
# Description: Free Sony Bravia 32" TV.
#
#
#
#       If you see this AD, it is still available.
#
#       Thanks for viewing.
#
# post id: 7715395017
#
#
#        posted:
#
#         2024-02-07 10:40
#
#
#
# Listing ID: 7715314438
#
# Title: Hospital bed (mendocino county)
#
# URL of image: https://images.craigslist.org/00505_fxm82liLXKz_0CI0t2_600x450.jpg
#
# Description: Military hospital bed. Good condition. Also have some supplies.
#
# post id: 7715314438
#
#
#        posted:
#
#         2024-02-07 07:40
#
#
#
# Listing ID: 7715530347
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715530347
#
#
#
# Listing ID: 7715423737
#
# Title: Free King size bed (scotts valley)
#
# URL of image: https://images.craigslist.org/00o0o_khdVFZsWVyN_0x20oM_600x450.jpg
#
# Description: Very comfy king size bed. Used in an Airbnb and people raved about it.
#
#       We closed our Airbnb so we don’t need it.
#
#       I know it’s raining, but if you need a bed and have a closed van or truck, give me a shout out.
#
#
#        show contact info
#
# post id: 7715423737
#
#
#        posted:
#
#         2024-02-07 11:45
#
#
#
# Listing ID: 7715414014
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715414014
#
#
#
# Listing ID: 7715453823
#
# Title: Free Workbench or Desk plus I'll give $50 cash for taking it away... (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/00n0n_c1MC7TniNc6_0CI0t2_600x450.jpg
#
# Description: Hello everyone, I have a free Desk or Workbench located in Martinez. It is a little heavy and you would need an extra person to lift it. It is 72 inches long, 30 inches wide and 37 inches tall. I'll also give you $50 cash for taking it away…Please only text or call if you can pick it up within an hour.
#
#
#        Please no scammers, offers to mail out or hand me fake cashiers checks, google id number verifications, texts to links or email links, etc. I only deal with the actual person face to face.
#
# post id: 7715453823
#
#
#        posted:
#
#         2024-02-07 13:01
#
#
#
#        updated:
#
#         2024-02-07 15:39
#
#
#
# Listing ID: 7715530107
#
# Title: Baby Cribs-Stokke crib /Pottery Barn / double umbrella stroller! Free! (lafayette / orinda / moraga)
#
# URL of image: https://images.craigslist.org/00606_jw3KcxzxNcG_0t20CI_600x450.jpg
#
# Description: Stokke Home Crib, white + mattress
#
#       Pottery Barn Crib, grey + mattress
#
#       Crib Sheets
#
#       double umbrella stroller
#
# post id: 7715530107
#
#
#        posted:
#
#         2024-02-07 16:55
#
#
#
# Listing ID: 7713160483
#
# Title: Humidifier - Holmes (nob hill)
#
# URL of image: https://images.craigslist.org/00505_jEcG8obzvX8_0CI0t2_600x450.jpg
#
# Description: Free working Holmes humidifer.  As seen in the picture there is a broken plastic piece; however, some super glue should easily fix it.
#
#
#       Checkout the other stuff I'm giving away for free here: https://sfbay.craigslist.org/search/sss?query=isaacwfreestuffsf
#
#
#       No holding unless I talked with you and you are on your way within the hour.
#
#
#       Text, call, or email me.
#
#
#       isaacwfreestuffsf
#
# post id: 7713160483
#
#
#        posted:
#
#         2024-01-31 14:08
#
#
#
#        updated:
#
#         2024-02-07 14:56
#
#
#
# Listing ID: 7715394295
#
# Title: IKEA queen mattress (san mateo)
#
# URL of image: https://images.craigslist.org/00404_dKvTatcLi8V_0CI0t2_600x450.jpg
#
# Description: We have a queen size ikea mattress in good condition. It was always slept on with a cover so is clean! Would need to be picked up by Friday afternoon bc we are moving first thing Saturday morning.
#
# post id: 7715394295
#
#
#        posted:
#
#         2024-02-07 10:39
#
#
#
# Listing ID: 7715544591
#
# Title: Free glass coffee table (San Francisco)
#
# URL of image: https://images.craigslist.org/00u0u_3fDKmpzvo5W_0hR0CI_600x450.jpg
#
# Description: Glass see through. 2 levels. -heavy
#
# post id: 7715544591
#
#
#        posted:
#
#         2024-02-07 17:53
#
#
#
# Listing ID: 7705769410
# Title: Nursing school CD’s (Santa Cruz)
#
# URL of image: https://images.craigslist.org/00g0g_xqpqng2aoy_0lM0CI_600x450.jpg
#
# Description: These CD’s are from 2005-2007. They came with my skill books and textbooks. I don’t know if anyone uses CD’s anymore?
#
# post id: 7705769410
#
#
#        posted:
#
#         2024-01-09 08:39
#
#
#
#        updated:
#
#         2024-02-07 17:05
#
#
#
# Listing ID: 7715466412
#
# Title: Wooden cabinet (inner sunset / UCSF)
#
# URL of image: https://images.craigslist.org/00M0M_5elXOFuHGL6_0lM0t2_600x450.jpg
#
# Description: Cabinet was used for T V and stereo.  Going out for recology pick up.  If you want it, please come take it. Sorry, no help or delivery, we are clearing out.
#
#       Also putting out nice large leather chair and foot ottoman.
#
#       It is also free for the taking.
#
#       Recology coming tomorrow (thurs) so come today!
#
#       1931 10th Avenue
#
# post id: 7715466412
#
#
#        posted:
#
#         2024-02-07 13:30
#
#
#
# Listing ID: 7715524329
#
# Title: Free Guitar Case (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/00909_8SH7DwQHLEK_0CI0hT_600x450.jpg
#
# Description: In ok shape but one of the closures has some corrosion.
#
#
#       Pick up in Martinez
#
# post id: 7715524329
#
#
#        posted:
#
#         2024-02-07 16:32
#
#
#
# Listing ID: 7715468334
#
# Title: Twin quilt (Vallejo)
#
# URL of image: https://images.craigslist.org/00202_eO8669KursJ_0t20CI_600x450.jpg
#
# Description: Comfy padded quilt
#
#       Clean
#
#       Also have a full size different color green and beige
#
# post id: 7715468334
#
#
#        posted:
#
#         2024-02-07 13:36
#
#
#
# Listing ID: 7711667389
#
# Title: 4 used 37" tires (Union City)
#
# URL of image: https://images.craigslist.org/00Z0Z_9iB4TWd823h_0CI0lM_600x450.jpg
#
# Description: 37" 12.50. R 17
#
#       BF Goodrich
#
#       4 total
#
#
#
#        show contact info
#
# post id: 7711667389
#
#
#        posted:
#
#         2024-01-26 22:28
#
#
#
#        updated:
#
#         2024-02-07 14:03
#
#
#
# Listing ID: 7715525646
#
# Title: Free (san jose south)
#
# URL of image: https://images.craigslist.org/00M0M_cUmknY79HJr_0t20CI_600x450.jpg
#
# Description: Free . One size not working
#
# post id: 7715525646
#
#
#        posted:
#
#         2024-02-07 16:37
#
#
#
# Listing ID: 7715524057
#
# Title: Body glove bodyboard (Hayward)
#
# URL of image: https://images.craigslist.org/00E0E_anXRZBhpLdL_0lN0CI_600x450.jpg
#
# Description: In decent shape
#
# post id: 7715524057
#
#
#        posted:
#
#         2024-02-07 16:31
#
#
#
# Listing ID: 7715484285
#
# Title: Bamboo charging station (Oakland)
#
# URL of image: https://images.craigslist.org/00K0K_lKWljswVqrv_0t20CI_600x450.jpg
#
# Description: Supply your own cables
#
#       As is
#
#       First come first served
#
# post id: 7715484285
#
#
#        posted:
#
#         2024-02-07 14:21
#
#
#
# Listing ID: 7715545952
#
# Title: Trampoline (santa rosa)
#
# URL of image: https://images.craigslist.org/00T0T_ckuR2ZI8lqa_0t20CI_600x450.jpg
#
# Description: Free trampoline
#
#       Our kid outgrew it
#
#
#       14 ft diameter
#
#       Good condition
#
#       Easy to replace parts if anything breaks down in the future.  We replaced everything but the aluminum structure a few years ago.
#
#
#       It disassembles easily so you can take it home in a small truck.
#
# post id: 7715545952
#
#
#        posted:
#
#         2024-02-07 17:59
#
#
#
# Listing ID: 7715520868
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715520868
#
#
#
# Listing ID: 7715509713
#
# Title: Bath light bar light (willow glen / cambrian)
#
# URL of image: https://images.craigslist.org/00u0u_3BhhmDG9w87_0t20CI_600x450.jpg
#
# Description: I have a new bathroom vanity light.
#
#
#       New in box.
#
#
#       Leave name and number if interested.
#
# post id: 7715509713
#
#
#        posted:
#
#         2024-02-07 15:41
#
#
#
# Listing ID: 7712229203
#
# Title: Free Concrete decorative posts (Castro Valley)
#
# URL of image: https://images.craigslist.org/00R0R_4cgLANKJKoY_0t20CI_600x450.jpg
#
# Description: Free
#
# post id: 7712229203
#
#
#        posted:
#
#         2024-01-28 19:30
#
#
#
#        updated:
#
#         2024-02-07 11:24
#
#
#
# Listing ID: 7715451413
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715451413
#
#
#
# Listing ID: 7715542366
#
# Title: Build-your-own birdhouse (nob hill)
#
# URL of image: https://images.craigslist.org/00p0p_laC0XbTIDhC_0lR0t2_600x450.jpg
#
# Description: I'm never going to build this :) would make a fun crafty gift for a loved one
#
# post id: 7715542366
#
#
#        posted:
#
#         2024-02-07 17:43
#
#
#
# Listing ID: 7710208630
#
# Title: Upright Piano (berkeley)
#
# URL of image: https://images.craigslist.org/00Z0Z_4HKmOjjy5q3_0CI0t2_600x450.jpg
#
# Description: hasn't been tuned in over 40 years, but it sounds amazing still
#
# post id: 7710208630
#
#
#        posted:
#
#         2024-01-22 15:01
#
#
#
#        updated:
#
#         2024-02-07 11:23
#
#
#
# Listing ID: 7715530720
#
# Title: Patio sliding glass doors (capitola)
#
# URL of image: https://images.craigslist.org/00R0R_d2n3YahN3cF_0lM0t2_600x450.jpg
#
# Description: Tempered glass patio sliding doors, there are 2. 4'x 7' in good shape. Single pane, unbroken. Metal aluminum frame
#
# post id: 7715530720
#
#
#        posted:
#
#         2024-02-07 16:57
#
#
#
# Listing ID: 7715308197
#
# Title: Free brown paper grocery bags (oakland rockridge / claremont)
#
# No image
#
# Description: I’ve been collecting brown paper grocery bags to reuse instead of recycle. These are great as packing material, wrapping paper, to cover books and textbooks, for use in art projects, or to donate to food banks. Email me to get some.
#
# post id: 7715308197
#
#
#        posted:
#
#         2024-02-07 07:24
#
#
#
# Listing ID: 7707133848
#
# Title: coffee table  - Thick cut glass top and havy Metal base (sausalito)
#
# URL of image: https://images.craigslist.org/00z0z_hfGb733cTZ_0t20CI_600x450.jpg
#
# Description: Contemporary style heavy table.
#
#       This was a very expensive table.  It is made of what looks like brass and copper. (I am not sure if its actual brass/copper or not)
#
#       Perfect condition.'
#
#       Priced for quick sale $50
#
#
#       Size"
#
#       36" long x 24" wide
#
#       22" high
#
#
#       If post is up, table is available.
#
#       If you'd like to come see it, please propose a time.  (Today Saturday is good)
#
#       There is usually someone around who can show it.
#
#       Thank you.
#
# post id: 7707133848
#
#
#        posted:
#
#         2024-01-13 08:27
#
#
#
#        updated:
#
#         2024-02-07 13:47
#
#
#
# Listing ID: 7713360347
#
# Title: Books & games (Hayward)
#
# URL of image: https://images.craigslist.org/00Q0Q_MSR0kUFulZ_0t20CI_600x450.jpg
#
# Description: 1 crate of books and 1 of games. Feel free to come look through it or take them all.
#
#
#       Tomorrow 9/2 from 8:30am-1pm.
#
#
#       34910 11th St, Union City, CA 94587
#
# post id: 7713360347
#
#
#        posted:
#
#         2024-02-01 08:56
#
#
#
#        updated:
#
#         2024-02-07 14:33
#
#
#
# Listing ID: 7713089936
#
# Title: Queen aerobed air mattress with small leak (San Francisco)
#
# URL of image: https://images.craigslist.org/00L0L_5pZPCfeEsj2_0t20CI_600x450.jpg
#
# Description: Queen size aerobed air mattress. Has a small leak that I couldn't find. Has a built in electric pump so you can just press the button to inflate it more if I gets a bit flat. Free pickup at potrero ave and Mariposa St.
#
# post id: 7713089936
#
#
#        posted:
#
#         2024-01-31 11:04
#
#
#
#        updated:
#
#         2024-02-07 15:34
#
#
#
# Listing ID: 7715495119
#
# Title: Infinity 6 kappa speakers (pair) (mill valley)
#
# URL of image: https://images.craigslist.org/01616_7fCR9GRxXDS_0uz0t2_600x450.jpg
#
# Description: These were top-of-the-line speakers in 1990. I bought them at The Good Guys when I was in college. They were bold and offered to double the difference on advertised prices and I managed to get these for like $100. So, it's not like I have much invested in these guys other than the story.
#
#
#       They are great but I have been moving them around for 3 decades and its TIME TO GO!
#
#
#       If you are the kind of person who can re-foam the cones these will be awesome. Or, maybe you want to cannibalize the parts- great. Or, chop it up for art. I don't care.
#
#
#       Email if interested
#
# post id: 7715495119
#
#
#        posted:
#
#         2024-02-07 14:55
#
#
#
# Listing ID: 7715500343
#
# Title: Free Bedroom Set (fairfield / vacaville)
#
# URL of image: https://images.craigslist.org/00F0F_bh0Q9CFEtF5_0gl0t2_600x450.jpg
#
# Description: Queen Bedframe with dresser n nightstand. No mattress or boxspring. Good condition. Just normal wear n tear with minor scuff marks.
#
# post id: 7715500343
#
#
#        posted:
#
#         2024-02-07 15:11
#
#
#
# Listing ID: 7715369693
#
# Title: Clay garden pipe (San Jose)
#
# URL of image: https://images.craigslist.org/00v0v_eF8tzgGnQsg_0lM0CI_600x450.jpg
#
# Description: Clay garden/ landscape pipe 12”x4” with a 3” diameter hole. Come by and pick up as many as you need.
#
# post id: 7715369693
#
#
#        posted:
#
#         2024-02-07 09:44
#
#
#
# Listing ID: 7715306849
#
# Title: FREE WOOD CHIPS! Clean! (Morgan Hill)
#
# URL of image: https://images.craigslist.org/01010_hlzSTXr7Aer_0hT0CI_600x450.jpg
#
# Description: Approximately 30 yards of wood chips, can deliver close by for free ￼
#
# post id: 7715306849
#
#
#        posted:
#
#         2024-02-07 07:20
#
#
#
# Listing ID: 7714717921
#
# Title: Construction safety (San Francisco)
# URL of image: https://images.craigslist.org/00606_luEgAKNl0eu_0CI0ik_600x450.jpg
#
# Description: 2 of this.
#
#       Text me
#
#       415 756 036nine.
#
# post id: 7714717921
#
#
#        posted:
#
#         2024-02-05 10:48
#
#
#
#        updated:
#
#         2024-02-07 12:47
#
#
#
# Listing ID: 7705495184
#
# Title: Couch with pull out bed (Hayward)
#
# URL of image: https://images.craigslist.org/00q0q_7b1LhAHpiYy_0CI0CI_600x450.jpg
#
# Description: If ad is up it is still available.
#
#
#       Very nice couch, but vinyl is flaking is corners.
#
#
#       Non-smoker
#
#       No pets
#
#
#       Will remove post once gone
#
# post id: 7705495184
#
#
#        posted:
#
#         2024-01-08 11:33
#
#
#
#        updated:
#
#         2024-02-07 10:38
#
#
#
# Listing ID: 7710582593
#
# Title: Free counter top (healdsburg / windsor)
#
# URL of image: https://images.craigslist.org/00N0N_8AOqUYel9CC_0CI0t2_600x450.jpg
#
# Description: Free counter top for bathroom, 6 feet by 22”. Call only
#
#        show contact info
#
# post id: 7710582593
#
#
#        posted:
#
#         2024-01-23 16:41
#
#
#
#        updated:
#
#         2024-02-07 14:12
#
#
#
# Listing ID: 7715517490
#
# Title: Books - A Beginners Guide to Creative Effects for Your Model Railroad (dublin / pleasanton / livermore)
#
# URL of image: https://images.craigslist.org/00R0R_hgujsDuwPFK_0t20CI_600x450.jpg
#
# Description: I have two cases of these books that were donated to me. Gave one book to a friend so I am left with 39 of these books. Hoping a local model railroad club can use them. Just trying to keep them out of the landfill.
#
#
#       Available available for immediate pick up near downtown Pleasanton.
#
# post id: 7715517490
#
#
#        posted:
#
#         2024-02-07 16:07
#
#
#
# Listing ID: 7715436732
#
# Title: Free wood chips (san jose east)
#
# URL of image: https://images.craigslist.org/00202_g9krEnS4WjM_0ww0oo_600x450.jpg
#
# Description: We have a 25 yard of wood chips for free on San Jose call to
#
#        show contact info
#
#       for a free deliver
#
#       (4cero8)77cero-7879
#
# post id: 7715436732
#
#
#        posted:
#
#         2024-02-07 12:15
#
#
#
#        updated:
#
#         2024-02-07 12:15
#
#
#
# Listing ID: 7715329244
#
# Title: Free Office Chair (san leandro)
#
# URL of image: https://images.craigslist.org/00x0x_4kraLRRJ8Fe_07K0ak_600x450.jpg
#
# Description: Used office chair. Arm-rest chipped on the front, otherwise all the mechanisms of the chair are fully functional.
#
# post id: 7715329244
#
#
#        posted:
#
#         2024-02-07 08:17
#
#
#
# Listing ID: 7710098837
#
# Title: Cal King bed with frame (petaluma)
#
# URL of image: https://images.craigslist.org/00a0a_a7r2iAbD3ya_0CI0t2_600x450.jpg
#
# Description: Clean Cal King bed includes mattress/box spring/metal frame. Very clean and comfortable.
#
# post id: 7710098837
#
#
#        posted:
#
#         2024-01-22 10:31
#
#
#
#        updated:
#
#         2024-02-07 09:16
#
#
#
# Listing ID: 7712855303
#
# No title
#
# No image
#
# No description
#
# Post ID: 7712855303
#
#
#
# Listing ID: 7715308763
#
# Title: Brand new Fluourescent Light Bulbs (San Jose)
#
# No image
#
# Description: I have 10 brand new fluorescent bulbs that is 15watt but puts out 60 watt equivalent standard bulbs.
#
# post id: 7715308763
#
#
#        posted:
#
#         2024-02-07 07:25
#
#
#
# Listing ID: 7715528321
#
# Title: Sub Woofer (walnut creek)
#
# URL of image: https://images.craigslist.org/00T0T_f0LYnjNF6Fw_0CI0t2_600x450.jpg
#
# Description: Subwoofer, center speaker & satellite speaker
#
# post id: 7715528321
#
#
#        posted:
#
#         2024-02-07 16:47
#
#
#
# Listing ID: 7715400905
#
# Title: Employee lockers (albany / el cerrito)
#
# URL of image: https://images.craigslist.org/00n0n_ausQwH3Yx47_0t20CI_600x450.jpg
#
# Description: Free.
#
#
#       Bank of 18 lockers. Steel.  Will clean up nicely with some spray paint.
#
#
#       Approx 72” tall x 36”w x 20” deep.
#
# post id: 7715400905
#
#
#        posted:
#
#         2024-02-07 10:54
#
#
#
# Listing ID: 7714234269
#
# Title: solid wood dinning room set (san jose south)
#
# URL of image: https://images.craigslist.org/00Q0Q_50ij0RLy3Nc_0CI0t2_600x450.jpg
#
# Description: This set comes with dinning table, one leaf, and six chairs. The wood and and upholstery are in good condition. The chairs are on wheels, they also spin and lean back. you pick up
#
# post id: 7714234269
#
#
#        posted:
#
#         2024-02-03 18:29
#
#
#
#        updated:
#
#         2024-02-07 15:59
#
#
#
# Listing ID: 7715542855
#
# Title: Books (albany / el cerrito)
#
# URL of image: https://images.craigslist.org/00V0V_kqLtMCVBU7y_0ut0t2_600x450.jpg
#
# Description: Dave Ramsey: The Total Money Makeover
#
#
#       Suze Orman: The Money Book for the Young, Fabulous & Broke
#
#
#       Wolf Hall: Book One of the Thomas Cromwell Trilogy
#
#
#       Intelligence Reframed
#
#
#       The Epidemic: The Rot of American Culture, Absentee and Permissive Parenting and the Resultant Plague of Joyless, Selfish Children
#
#
#       Please take all books and regift any
#
#
#       Please lmk when you can pick up (near el cerrito plaza Bart), thanks!
#
# post id: 7715542855
#
#
#        posted:
#
#         2024-02-07 17:45
#
#
#
#        updated:
#
#         2024-02-07 18:39
#
#
#
# Listing ID: 7715394067
#
# Title: Blood pressure monitor w leak (cupertino)
#
# URL of image: https://images.craigslist.org/01414_edoQFBsQyfI_0t20CI_600x450.jpg
#
# Description: If you can repair the air leak nears the connection, where I have added yellow gasket material, it would be a good blood pressure monitor.
#
#
#       Or, you can use it for parts. For example, the cuff is in good and clean shape.
#
# post id: 7715394067
#
#
#        posted:
#
#         2024-02-07 10:38
#
#
#
#        updated:
#
#         2024-02-07 10:39
#
#
#
# Listing ID: 7715517244
#
# Title: Free PS4 with controllers no games (willow glen / cambrian)
#
# No image
#
# Description: PS4 with controllers but no games.  Was stored for a few years since children went to college.  Should be working fine.
#
#
#
#
#
#       No holds.  First come first serve.
#
#
#
#
#
#
#        show contact info
#
# post id: 7715517244
#
#
#        posted:
#
#         2024-02-07 16:07
#
#
#
# Listing ID: 7714703932
#
# Title: Free 2 cushions (sonoma)
#
# URL of image: https://images.craigslist.org/00C0C_bWkB7Wuolxh_0lM0t2_600x450.jpg
#
# Description: 28" x 21" x 6.5" each
#
# post id: 7714703932
#
#
#        posted:
#
#         2024-02-05 10:18
#
#
#
#        updated:
#
#         2024-02-07 11:01
#
#
#
# Listing ID: 7714558929
#
# Title: 3Drawer CD holder storage cabinet case (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/01010_ho3QAmYhRAw_0CI0t2_600x450.jpg
#
# Description: 3Drawer CD holder storage cabinet case
#
#
#       16th Ave between Geary and Clement
#
# post id: 7714558929
#
#
#        posted:
#
#         2024-02-05 00:20
#
#
#
#        updated:
#
#         2024-02-07 15:35
#
#
#
# Listing ID: 7711571686
#
# Title: Free shelves and desk (San Jose)
#
# URL of image: https://images.craigslist.org/00Y0Y_5BcXxaV74Lk_0hr0CI_600x450.jpg
#
# Description: Free
#
#
#        show contact info
#
# post id: 7711571686
#
#
#        posted:
#
#         2024-01-26 14:27
#
#
#
#        updated:
#
#         2024-02-07 10:27
#
#
#
# Listing ID: 7715533609
#
# Title: Several free shipping packing storage cardboard medium size boxes box (san jose north)
#
# URL of image: https://images.craigslist.org/00Y0Y_eDBLIRMsEzY_0t20CI_600x450.jpg
#
# Description: Several free shipping packing storage cardboard medium size boxes box
#
#
#       Pick up in North San Jose
#
#
#       Will provide exact address when picking up
#
#
#       First come first serve
#
#
#       Due to the off and on rain, I won't leave them outside and I can bring them out when you come pick up
#
# post id: 7715533609
#
#
#        posted:
#
#         2024-02-07 17:08
#
#
#
#        updated:
#
#         2024-02-07 17:08
#
#
#
# Listing ID: 7712891804
#
# Title: 1978 Toyota Celica parts, miscellaneous. Take all for free (cupertino)
#
# URL of image: https://images.craigslist.org/00909_1q1QlUZh0tN_0CI0t2_600x450.jpg
#
# Description: 1978 Toyota Celica parts, miscellaneous. Take all for free. As seen in photo. Come get tonight. Cupertino. Send phone number.
#
# post id: 7712891804
#
#
#        posted:
#
#         2024-01-30 17:40
#
#
#
#        updated:
#
#         2024-02-07 11:28
#
#
#
# Listing ID: 7712443048
#
# Title: Free, working record player/cabinet (Bolinas)
#
# URL of image: https://images.craigslist.org/00K0K_10fjZZIHgZX_0t20CI_600x450.jpg
#
# Description: Getting rid of this old vintage record player/cabinet. Built in speakers, radio, cassette player. It’s working, but sound is slightly off. With a little work it could be really cool, or just use as-is for radio, cassette, or records.
#
#
#       Free with pickup in Bolinas.
#
#
#       Text me
#
#        show contact info
#
# post id: 7712443048
#
#
#        posted:
#
#         2024-01-29 12:04
#
#
#
#        updated:
#
#         2024-02-07 11:55
#
#
#
# Listing ID: 7715472948
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715472948
#
#
#
# Listing ID: 7715519519
#
# Title: Free 42 inch tv, Dark screen (santa cruz)
#
# URL of image: https://images.craigslist.org/01414_cJhzJYxW0S4_0CI0t2_600x450.jpg
#
# Description: Hi, I have a free 42" tv that someone may want. Please know that the picture is darker than usual, so you may not want it. I used like this for quite a while. Comes with remote.
#
#
#       Near blacks beach. Message if you'd like it.
#
#
#       Thank You
#
# post id: 7715519519
#
#
#        posted:
#
#         2024-02-07 16:14
#
#
#
# Listing ID: 7715305433
#
# Title: Plywood (milpitas)
#
# URL of image: https://images.craigslist.org/00v0v_6XiPUGb9Ftn_0qn0t2_600x450.jpg
#
# Description: 1025 Sinclair frontage Road Milpitas, California 95035
#
#
#       Free plywood! Come get it. Don't message me. Just come get it.
#
# post id: 7715305433
#
#
#        posted:
#
#         2024-02-07 07:16
#
#
#
# Listing ID: 7715459120
# Title: Free sandbags (San Francisco)
#
# URL of image: https://images.craigslist.org/00606_5XOCWSCzjek_0t20CI_600x450.jpg
#
# Description: Free sandbags. Got for the storms, turns out we already had some.  I can leave outside if you want to come grab them.
#
# post id: 7715459120
#
#
#        posted:
#
#         2024-02-07 13:12
#
#
#
# Listing ID: 7715449570
#
# Title: FREE desk chair with arms (walnut creek)
#
# URL of image: https://images.craigslist.org/00X0X_aD4Kus0rgBJ_0lM0t2_600x450.jpg
#
# Description: FREE  Captain's chair with arms, comfortable cushions upholstered in tan micro-fiber fabric. Adjustable seat and back, on casters. No animals in residence. 42"H, 27"W, 20"D. Normal wear, no tears or stains. Plan to move chair down two flights of stairs, I'm injured and can't carry anything. FREE
#
# post id: 7715449570
#
#
#        posted:
#
#         2024-02-07 12:49
#
#
#
# Listing ID: 7711928339
#
# Title: SOFAS! Beige Sofa for free - 3 pieces (menlo park)
#
# URL of image: https://images.craigslist.org/00000_h3h3bk1azyV_0pO0jm_600x450.jpg
#
# Description: Lovely 3-piece sofa for a good home.
#
#       3 chairs are reclinable, one needs a screw. A little table with storage.
#
#       Pillows are not included
#
#       it's free! First come first serve, we don't hold it. Bring help and a truck.
#
# post id: 7711928339
#
#
#        posted:
#
#         2024-01-27 16:47
#
#
#
#        updated:
#
#         2024-02-07 10:03
#
#
#
# Listing ID: 7714559986
#
# Title: Land line phone (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/00N0N_8ZjabgD2uQT_0lM0t2_600x450.jpg
#
# Description: Land line phone
#
#       16th Ave between Geary and Clement
#
# post id: 7714559986
#
#
#        posted:
#
#         2024-02-05 00:44
#
#
#
#        updated:
#
#         2024-02-07 15:34
#
#
#
# Listing ID: 7715335093
#
# Title: Wood Benching Tables (palo alto)
#
# URL of image: https://images.craigslist.org/00r0r_jgCfW06SXft_0oc0wg_600x450.jpg
#
# Description: Currently 18ea 36x72 Wood Tables and 36ea Wood Benches
#
#
#       All are in OK condition
#
#
#       They are all FREE...
#
#
#       Currently in a downtown Palo Alto facility that went out of business
#
#
#       You must provide your own labor and a large box truck to have everything fit
#
#
#       Must take a bunch of them...1 or 2 will not be allowed (just too much time...sorry)
#
#
#       Thanks!
#
# post id: 7715335093
#
#
#        posted:
#
#         2024-02-07 08:31
#
#
#
#        updated:
#
#         2024-02-07 10:42
#
#
#
# Listing ID: 7715474218
#
# Title: Free Amazon boxes (mountain view)
#
# URL of image: https://images.craigslist.org/00M0M_koGgnxQIQh_0dW0iw_600x450.jpg
#
# Description: Various sizes
#
#       Great for moving, shipping products, or organizing
#
#       Pick up off my porch
#
#       I'll delete ad when boxes are gone
#
# post id: 7715474218
#
#
#        posted:
#
#         2024-02-07 13:53
#
#
#
# Listing ID: 7715494220
#
# Title: FREE Bookshelf Vintage Wall Unit Bookcase Solid Wood (dublin / pleasanton / livermore)
#
# URL of image: https://images.craigslist.org/00202_18yJ6BIyfzT_0k30t2_600x450.jpg
#
# Description: Vintage 70s wall unit/bookcase. One moveable shelf. Storage on bottom.
#
#       72” tall x 46” wide x 13” deep.
#
#       Solid wood. Well made and heavy.
#
#
#       Must be picked up by Sunday 2/11 6pm.
#
# post id: 7715494220
#
#
#        posted:
#
#         2024-02-07 14:52
#
#
#
# Listing ID: 7715539414
#
# Title: Free quality furnishings, etc (Berkeley)
#
# URL of image: https://images.craigslist.org/00P0P_fNyhPdsmMVB_0t20CI_600x450.jpg
#
# Description: 7’ bookshelf, 51” and 84” sofa beds, expandable rolling table, drafting table, wicker hamper and baskets, twin-queen bed frame, small bookshelf.  All free, all in good shape.
#
#
#       Texts preferred.
#
# post id: 7715539414
#
#
#        posted:
#
#         2024-02-07 17:30
#
#
#
#        updated:
#
#         2024-02-07 18:53
#
#
#
# Listing ID: 7707638711
#
# Title: CPCU commercial insurance textbooks FREE (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/00N0N_hi3TkCUHf06_0t20CI_600x450.jpg
#
# Description: FREE Commercial Insurance CPCU study books for liability and property insurance.
#
#       Used as study guides around 2001 but probably not up to date for the tests but good reference guides for commercial insurance. Pickup near concord / clayton border
#
# post id: 7707638711
#
#
#        posted:
#
#         2024-01-15 00:36
#
#
#
#        updated:
#
#         2024-02-07 11:48
#
#
#
# Listing ID: 7715387630
#
# Title: Foam Insulation Board 1/2"" thick (petaluma)
#
# URL of image: https://images.craigslist.org/00h0h_diEtN66pJ8t_0CI0t2_600x450.jpg
#
# Description: R-TECH Foam Insulation Board 1/2" thick, 3 pieces.
#
#
#       2 measure 46"' X 48"
#
#
#       1 measures about 47" X 48" with cutout.
#
# post id: 7715387630
#
#
#        posted:
#
#         2024-02-07 10:24
#
#
#
# Listing ID: 7715405474
#
# Title: 6 drapes - heavy duty (berkeley north / hills)
#
# URL of image: https://images.craigslist.org/01414_3dR7NQP6frZ_0MM132_600x450.jpg
#
# Description: 6 drapes - that is 3 sets of 2 panel drapes. Each one about 3' wide by 5' long aproximately. Very heavy duty black out  curtains. White with blue interiors. These have metal hooks to hang them already installed in the curtains.  Nice quality and heavy duty and clean and useable. If you want them let me know when you can pick up and I'll end the address. AVAILABLE THURSDAY AND BEYOND.
#
# post id: 7715405474
#
#
#        posted:
#
#         2024-02-07 11:04
#
#
#
# Listing ID: 7715442405
#
# Title: Small sofa (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/00T0T_2B2mKKqkhZQ_0ji0ew_600x450.jpg
#
# Description: I have a small sofa, pretty old and faded, but it's free. I believe it opens into a bed.
#
#
#       Dimensions: 54" (w) x 30" (d) x 30" (h)
#
#
#       It can be disassembled for easier transportation. If anyone would like to take a look, let me know.
#
# post id: 7715442405
#
#
#        posted:
#
#         2024-02-07 12:30
#
#
#
# Listing ID: 7715507681
#
# Title: Couch + Sofa  FREE (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/01515_7sJqWYwW1YM_0lM0t2_600x450.jpg
#
# Description: I am updating my furniture and have an extra couch + matching single chair), used condition.
#
#       - Dimensions: 77"Wx33"Dx32"H (3 seat sofa) + 23"Wx 33"Dx 32"H (1 seat sofa)
#
#       - Color: Dark Chocolate (Brown)
#
#       - Seats: 3+1 (2 pcs)
#
#       - Material: Vinyl
#
#       You need another person to help you carry.
#
#       Text or email to coordinate. Thank you!
#
# post id: 7715507681
#
#
#        posted:
#
#         2024-02-07 15:35
#
#
#
# Listing ID: 7715531249
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715531249
#
#
#
# Listing ID: 7709936764
#
# Title: TV/Media Stand (lafayette / orinda / moraga)
#
# URL of image: https://images.craigslist.org/00H0H_853kb9oeZEn_0CI0t2_600x450.jpg
#
# Description: Espresso media stand
#
#       Well loved - in good condition with some scratches and marks (pictured)
#
# post id: 7709936764
#
#
#        posted:
#
#         2024-01-21 21:19
#
#
#
#        updated:
#
#         2024-02-07 11:02
#
#
#
# Listing ID: 7715323804
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715323804
#
#
#
# Listing ID: 7715365337
#
# Title: TWO (2) FULL BRAND NEW FULL SIZE TREADMILLS  - FREE (SAN LEANDRO)
#
# URL of image: https://images.craigslist.org/00y0y_cVSJlDvOp5o_0bu08x_600x450.jpg
#
# Description: TWO BRAND NEW NAME BRAND FULL SIZE TREADMILLS BOTH NEEDING RATHER MINOR REPAIR TO BE USEABLE.
#
#
#       ONE, FOR EXAMPLE, IS AN XTERRA 400 RETAILING FOR BETWEEN $800 , $1000.
#
#       THE OTHER IS EQUAL TO OR BETTER.
#
#
#       It is likely that  simple wire connector in at least one of the machines.
#
#       Come and pick up asap.
#
# post id: 7715365337
#
#
#        posted:
#
#         2024-02-07 09:35
#
#
#
# Listing ID: 7713357032
#
# Title: FREE OFFICE DESKS 3X and one large conference table as shown (dublin / pleasanton / livermore)
#
# URL of image: https://images.craigslist.org/01010_kpHzLP27Vyp_0t40CI_600x450.jpg
#
# Description: Office is moving.  All that you are is still free to take.   desks are available as shown
#
#
#       Nice conference room table No stairs, easy access right off Preston Ave, Livermore.
#
#
#       Ready today and tomorrow to take.
#
# post id: 7713357032
#
#
#        posted:
#
#         2024-02-01 08:48
#
#
#
#        updated:
#
#         2024-02-07 16:54
#
#
#
# Listing ID: 7713900033
#
# Title: FREE CHAIR  HEADBOARD  FILING CABINET (palo alto)
#
# URL of image: https://images.craigslist.org/00e0e_cl12KoRZoaZ_0t20CI_600x450.jpg
#
# Description: FREE ITEMs are pictured in the first 12 pictures.  Small fee items are in pics 13-end
#
#
#       HEADBOARD is queen size.
#
#
#       This rolling file bin / cabinet is everything right at your fingertips and it's got its own cover as well. Made by File Shuttle this retro cabinet is super convenient. It includes the hanging folders that you see too.$30
#
#
#       Plastic stacking drawers in white. Drawers work good. text for dimensions This is a set of three for $15 or the cracked one is free.
#
#
#       Accordion portable files:
#
#       1) 19 pockets with label tabs and a zippered pouch FREE
#
#       2) 21 pockets alphabetized, numbered and labels with handle for easy carrying and twisting lock. $10
#
#
#       Beige portable file cabinet with hanging folders. The handle makes it easy to carry and easy to operate locks - $10
#
#
#       This is a cash only sale. Please text for dimensions or for more info. Thanks.
#
#
#
#
#       Redrope
#
# post id: 7713900033
#
#
#        posted:
#
#         2024-02-02 17:39
#
#
#
#        updated:
#
#         2024-02-07 14:09
#
#
#
# Listing ID: 7715493835
#
# Title: Subaru teeeter speakers (san jose south)
#
# No image
#
# Description: I have a pair of Subaru tweeter speakers that was from a 2013 Outback. They’re in good condition.
#
# post id: 7715493835
#
#
#        posted:
#
#         2024-02-07 14:50
#
#
#
# Listing ID: 7715399300
#
# Title: Free Six-Sided Picnic Table + Umbrella (hayward / castro valley)
#
# URL of image: https://images.craigslist.org/00404_g2AbtZRRIFb_0t20CI_600x450.jpg
#
# Description: Hand-made picnic table looking for a new home. The table is 63 ½ inches across and 30 inches high. The umbrella is a little worn and has a few holes. The table does not come apart. You will need a truck or large van to move it. Pickup in Castro Valley.
#
# post id: 7715399300
#
#
#        posted:
#
#         2024-02-07 10:50
#
#
#
# Listing ID: 7715468312
#
# Title: Round 1/4" Glass for Table Top (richmond / point / annex)
#
# URL of image: https://images.craigslist.org/00X0X_gMtUROp5b5G_0yB0t2_600x450.jpg
#
# Description: Protect your wood table with this 1/4" round glass with a flat polished edge.
#
# post id: 7715468312
#
#
#        posted:
#
#         2024-02-07 13:36
#
#
#
# Listing ID: 7714733644
#
# Title: Soap Holder (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/00A0A_dia42Rg4WUe_0lM0t2_600x450.jpg
#
# Description: Soap Holder
#
#       16th Ave between Geary and Clement
#
# post id: 7714733644
#
#
#        posted:
#
#         2024-02-05 11:23
#
#
#
#        updated:
#
#         2024-02-07 15:34
#
#
#
# Listing ID: 7715347381
#
# Title: Household Items (walnut creek)
#
# URL of image: https://images.craigslist.org/00y0y_8sJDb9qvHda_0CI0t2_600x450.jpg
#
# Description: Misc. Household Items:
#
#
#       (9" H) Candle Holder
#
#       Curve Ruler
#
#       Metal Picture Hooks
#
#       Plastic Grocery Bags
#
#       Small Square Food Storage Container
#
#       (7") Small Clear Glass Plate
#
#
#
#       Call (925) 603-FREE [3733]
#
# post id: 7715347381
#
#
#        posted:
#
#         2024-02-07 09:00
#
#
#
# Listing ID: 7715509943
#
# Title: Treadmill (lafayette / orinda / moraga)
#
# No image
#
# Description: Free treadmill- high quality in excellent shape. You need a truck to pick it up and it needs partially disassembled to get through doorway.
#
# post id: 7715509943
#
#
#        posted:
#
#         2024-02-07 15:42
#
#
#
# Listing ID: 7715532652
#
# Title: Multiple metal bed frames (willow glen / cambrian)
#
# No image
#
# Description: Come and get!
#
#
#       1104 norval way San Jose 95125
#
# post id: 7715532652
#
#
#        posted:
#
#         2024-02-07 17:05
#
#
#
# Listing ID: 7715330009
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715330009
#
#
#
# Listing ID: 7715372780
#
# Title: Free antique arm chair (San Francisco)
#
# URL of image: https://images.craigslist.org/01212_hnZIuPKa6mw_0sh0CI_600x450.jpg
#
# Description: Top piece is broken as shown in photo. Needs a little TLC, but a unique beautiful piece!
#
#
#       23” wide at the widest measurement (arm rest to arm rest); 39” at the tallest measurement (including the trim piece on the backrest).
#
# post id: 7715372780
#
#
#        posted:
#
#         2024-02-07 09:51
#
#
#
# Listing ID: 7710945210
#
# Title: TV 40” Samsung “FREE” (san rafael)
#
# URL of image: https://images.craigslist.org/00E0E_icFdIRfsukx_0CI0qJ_600x450.jpg
#
# Description: 40” Samsung TV
#
#       Model HL-S4266
#
#       Works perfectly for the exception it might need ON/OFF inner switch, it’s-been acting up, keeps shutting off.
#
#       “FREE for the asking”
#
#       Note:It’s a bit heavy because it’s an older model.
#
# post id: 7710945210
#
#
#        posted:
#
#         2024-01-24 17:38
#
#
#
#        updated:
#
#         2024-02-07 11:43
#
#
#
# Listing ID: 7715347533
#
# Title: DVD (walnut creek)
#
# URL of image: https://images.craigslist.org/00606_jRRNVWZjm8T_0co0gw_600x450.jpg
#
# Description: DVD (by Darryl Anka)
#
#
#
#       Call (925) 603-FREE [3733]
#
# post id: 7715347533
#
#
#        posted:
#
#         2024-02-07 09:00
#
#
#
# Listing ID: 7715548665
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715548665
#
#
#
# Listing ID: 7715474805
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715474805
#
#
#
# Listing ID: 7715534211
#
# Title: Mlbor-0 (pittsburg / antioch)
#
# No image
#
# Description: Mlbor-0 100s de Mexico
#
#       1 cajetilla x 11
#
#       Caja completa (10 cajetillas x 100)
#
#
#       Contactame al
#
#
#       Nueve 25 tres tres 4 dos 7 8 nueve
#
# post id: 7715534211
#
#
#        posted:
#
#         2024-02-07 17:10
#
#
#
#        updated:
#
#         2024-02-07 17:12
#
#
#
# Listing ID: 7708533912
#
# Title: Honda Z50 Flywheels. Mini Trail.  CT70 (santa clara)
#
# URL of image: https://images.craigslist.org/00Y0Y_ciZGMIMcNtS_0CI0t2_600x450.jpg
#
# Description: Four flywheel rotors.
#
# post id: 7708533912
#
#
#        posted:
#
#         2024-01-17 13:23
#
#
#
#        updated:
#
#         2024-02-07 11:01
#
#
#
# Listing ID: 7706875886
#
# Title: Classic Titles (saratoga)
#
# URL of image: https://images.craigslist.org/00R0R_8uidUtc2ctD_0t20CI_600x450.jpg
#
# Description: Group of books
#
#
#
#
#       Pick up in Saratoga
#
#       Thank you
#
#
#       No Trolls
#
# post id: 7706875886
#
#
#        posted:
#
#         2024-01-12 11:18
#
#
#
#        updated:
#
#         2024-02-07 18:08
#
#
#
# Listing ID: 7715390300
#
# Title: boxes of various sizes with packing materials of various types for al (ingleside / SFSU / CCSF)
#
# URL of image: https://images.craigslist.org/00z0z_i1992jvrPJX_0iP0CI_600x450.jpg
#
# Description: A bunch of different sized boxes, on the small to medium side. Also a bunch of used backing materials and a box of stryofoam peanuts
#
# post id: 7715390300
#
#
#        posted:
#
#         2024-02-07 10:30
#
#
#
# Listing ID: 7715533346
#
# Title: Newco coffee maker (foster city)
#
# URL of image: https://images.craigslist.org/00B0B_gYRwHyOdaeI_08J0cm_600x450.jpg
#
# Description: Free
#
#
#       Restaurant style coffee maker, requires water line.
#
#
#       Last used Jun 2020, cleaning out storage unit.
#
#
#       Please email, no  phone, no text.
#
# post id: 7715533346
#
#
#        posted:
#
#         2024-02-07 17:07
#
#
#
# Listing ID: 7714763829
#
# Title: Free Easter Decorations (palo alto)
#
# URL of image: https://images.craigslist.org/00202_kc2HXcin5UZ_0uh0t2_600x450.jpg
#
# Description: Two small Easter decorations available for free. Please take them both. Pickup only.
#
# post id: 7714763829
#
#
#        posted:
#
#         2024-02-05 12:34
#
#
#
#        updated:
#
#         2024-02-07 14:29
#
#
#
# Listing ID: 7715524228
#
# Title: Receiver (walnut creek)
#
# URL of image: https://images.craigslist.org/00W0W_5mLCInwmLCH_0CI0t2_600x450.jpg
#
# Description: Yamaha NaturalSound Av Receiver RXV473
#
# post id: 7715524228
#
#
#        posted:
#
#         2024-02-07 16:31
#
#
#
#        updated:
#
#         2024-02-07 16:38
#
#
#
# Listing ID: 7715324233
#
# Title: 2 Vessel bathroom sink (oakland east)
#
# URL of image: https://images.craigslist.org/00Y0Y_fQTONhoCfXg_0CI0hT_600x450.jpg
#
# Description: I for free 2 vessel bathroom sink with the vanity that I removed from a bathroom We are remodeling  ,You need to put a counter over the vanity to install the sinks, or You can use them for any other project,  if you are interested let me know.
#
# post id: 7715324233
#
#
#        posted:
#
#         2024-02-07 08:06
#
#
#
# Listing ID: 7707527407
#
# Title: LARGE DESK WITH DRAWERS (Fremont)
#
# URL of image: https://images.craigslist.org/00c0c_2SWaSGpCyYN_0lM0CI_600x450.jpg
#
# Description: Large brown wooden desk with drawers and cabinet (just the door tho)
#
#       61” wide x 25.5” d x 29” h
#
#       Free on porch 4624 Kane Ct, Fremont
#
#       Just come get it :)
#
# post id: 7707527407
#
#
#        posted:
#
#         2024-01-14 13:15
#
#
#
#        updated:
#
#         2024-02-07 10:42
#
#
#
# Listing ID: 7715525602
# Title: Moving ***Free*** Household Items & Furniture (San Francisco)
#
# URL of image: https://images.craigslist.org/00s0s_3bOVBOobVKs_0lM0CI_600x450.jpg
#
# Description: 150 Valencia (Between Market & Duboce)
#
#
#       If posting is still up item is here.
#
#
#       No time unfortunately to respond to any inquiries.    First posted items are a lamp and MCM  hilt in Headboard.
#
#
#       More to come ….
#
# post id: 7715525602
#
#
#        posted:
#
#         2024-02-07 16:37
#
#
#
#        updated:
#
#         2024-02-07 16:55
#
#
#
# Listing ID: 7715363491
#
# Title: Floor plastic water proof sheet (Oakland)
#
# URL of image: https://images.craigslist.org/00u0u_4ra2903ypgQ_0t20CI_600x450.jpg
#
# Description: Probably almost a whole sheet. Only did our camper truck
#
# post id: 7715363491
#
#
#        posted:
#
#         2024-02-07 09:31
#
#
#
# Listing ID: 7715403901
#
# Title: Free latch hook rug yarn (Danville)
#
# URL of image: https://images.craigslist.org/00z0z_ck7wVKIbAN3_0CI0t2_600x450.jpg
#
# Description: Free latch hook rug yarn
#
#
#       Must take all
#
#
#       Located in Danville
#
# post id: 7715403901
#
#
#        posted:
#
#         2024-02-07 11:00
#
#
#
# Listing ID: 7710482416
#
# Title: Free tools airless, shredder, conduit (bernal heights)
#
# URL of image: https://images.craigslist.org/00303_hLqkSajLVtM_0CI0hq_600x450.jpg
#
# Description: That is all that is left. 74nine Moultrie Street
#
# post id: 7710482416
#
#
#        posted:
#
#         2024-01-23 11:52
#
#
#
#        updated:
#
#         2024-02-07 07:24
#
#
#
# Listing ID: 7713144463
#
# Title: Used mattress - FREE (mission district)
#
# No image
#
# Description: Moving sale. Free used mattress.
#
# post id: 7713144463
#
#
#        posted:
#
#         2024-01-31 13:22
#
#
#
#        updated:
#
# ...
#
#
#
# Listing ID: 7715358339
#
# Title: Maytag stacked washer/dryer (laurel hts / presidio)
#
# URL of image: https://images.craigslist.org/00N0N_jNiRXVoFZVq_0t20CI_600x450.jpg
#
# Description: Maytag Dependable Care high capacity washer/dryer
#
#
#       They both appear to work when plugged in, though have not actually done a test run. Likely 15-20yrs old.
#
# post id: 7715358339
#
#
#        posted:
#
#         2024-02-07 09:20
#
#
#
# Listing ID: 7711829052
#
# Title: Ikea high chair (Santa Cruz)
#
# URL of image: https://images.craigslist.org/00u0u_gnfLDq8FcZu_0t20CI_600x450.jpg
#
# Description: Ikea high chair, one of the tray clips broke on one corner but the tray still stays on well. We’ll loved little high chair
#
# post id: 7711829052
#
#
#        posted:
#
#         2024-01-27 11:31
#
#
#
#        updated:
#
#         2024-02-07 09:04
#
#
#
# Listing ID: 7715449942
#
# Title: Free Storage Cabinet Plus I'll give you $20 cash for gas (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/00909_fFb4cAwmb9c_0ax0t2_600x450.jpg
#
# Description: Hello everyone, I have a Free storage cabinet located in Martinez. It can store a lot of stuff and measures 93.5 inches tall, 21 inches wide and 25 inches deep. Plus I will give you $20 cash for taking it away. You are more than welcome to pick it up now until 2:30PM today, or it would have to be tomorrow.... Please only text or call if you can pick it up within an hour.
#
#
#        Please no scammers, offers to mail out or hand me fake cashiers checks, google id number verifications, texts to links or email links, etc. I only deal with the actual person face to face.
#
# post id: 7715449942
#
#
#        posted:
#
#         2024-02-07 12:50
#
#
#
#        updated:
#
#         2024-02-07 15:40
#
#
#
# Listing ID: 7712840017
#
# Title: Storage bin (for yard waste) (oakland rockridge / claremont)
#
# No image
#
# Description: This is NOT suitable for storage since the lid doesn't lock securely and water has the ability to get inside.
#
#
#       Best used to pick up leaves, yard waste, etc.
#
# post id: 7712840017
#
#
#        posted:
#
#         2024-01-30 14:37
#
#
#
#        updated:
#
#         2024-02-07 10:39
#
#
#
# Listing ID: 7715450519
#
# Title: 2013 Highlander Rear Area Mat (sunnyvale)
#
# URL of image: https://images.craigslist.org/00G0G_ldmvuikd2fk_0CI0t2_600x450.jpg
#
# Description: We no longer have this vehicle, and had pulled this out when we purchased a heavy duty rubber mat to put in the back.
#
# post id: 7715450519
#
#
#        posted:
#
#         2024-02-07 12:52
#
#
#
# Listing ID: 7715461356
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715461356
#
#
#
# Listing ID: 7715403985
#
# Title: box of shoes. Mostly size 7.5 female.  and size 12 male (berkeley)
#
# URL of image: https://images.craigslist.org/01616_7SC3T7Mf99F_0MM132_600x450.jpg
#
# Description: Bis box of used shoes including some nice snow boots. Lots of life left on most. Must take them all. If you want them tell me when you can pick up and I'll end the address. Available Thursday and after.
#
# post id: 7715403985
#
#
#        posted:
#
#         2024-02-07 11:01
#
#
#
# Listing ID: 7715481682
#
# Title: Garage Grade Free Folding Table (san jose west)
#
# URL of image: https://images.craigslist.org/00303_fbqRSP6YgOO_0t20CI_600x450.jpg
#
# Description: Plywood Top - Approximately 32" x 72".  Metal folding legs, with lockouts.  Plastic feet/tips.  Pretty clean/solid.
#
#
#       Used with a tablecloth at Xmas.
#
#
#       Sanded and wrapped the plywood edge with heavy packaging tape (to avoid Splinters!) Also taped over the metal frame to keep any rust off of folks knees...
#
#
#       Free!
#
#       Please respond with "Table" and your phone number for contact.
#
# post id: 7715481682
#
#
#        posted:
#
#         2024-02-07 14:14
#
#
#
# Listing ID: 7715412792
#
# Title: Free small microwave (San Leandro)
#
# URL of image: https://images.craigslist.org/01717_dw0G7s9NvQo_0CI0t2_600x450.jpg
#
# Description: The bulb flickers and the silver plate inside needs to be tapers back together. Out on patio at 14848 midland rd, San Leandro, Will remove post when it’s gone
#
# post id: 7715412792
#
#
#        posted:
#
#         2024-02-07 11:21
#
#
#
# Listing ID: 7715401628
#
# Title: 3.5 Floppy Diskettes (san jose east)
#
# No image
#
# Description: 100 3.5 floppy diskettes formatted and tested.
#
#       Pick up is preferred.
#
# post id: 7715401628
#
#
#        posted:
#
#         2024-02-07 10:55
#
#
#
# Listing ID: 7715364328
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715364328
#
#
#
# Listing ID: 7714206761
#
# No title
#
# No image
#
# No description
#
# Post ID: 7714206761
#
#
#
# Listing ID: 7712206329
#
# Title: Free counter top (healdsburg / windsor)
#
# URL of image: https://images.craigslist.org/00N0N_8AOqUYel9CC_0CI0t2_600x450.jpg
#
# Description: Free counter top with sink free, it is 6feet long and 22” wide call only
#
#        show contact info
#
# post id: 7712206329
#
#
#        posted:
#
#         2024-01-28 17:21
#
#
#
#        updated:
#
#         2024-02-07 14:13
#
#
#
# Listing ID: 7711266767
#
# Title: Available: Large Table with water damage (oakland rockridge / claremont)
#
# URL of image: https://images.craigslist.org/00R0R_iUksaIF1ZOo_0CI0t2_600x450.jpg
#
# Description: If this is up it’s available.
#
#
#       This was a beautiful table but has unfortunately been sitting in the rain. Covered now but come save it. Needs some love.
#
#
#       Dimensions:
#
#       60” wide
#
#       30” deep
#
#       30” tall
#
# post id: 7711266767
#
#
#        posted:
#
#         2024-01-25 16:31
#
#
#
#        updated:
#
#         2024-02-07 07:22
#
#
#
# Listing ID: 7715496150
#
# Title: Baby gate 28-36 inches (sunset / parkside)
#
# URL of image: https://images.craigslist.org/01414_erDMaXEgvXx_0lM0t2_600x450.jpg
#
# Description: Free baby gate for 28-36 inch wide space.  Pushes outwards
#
# post id: 7715496150
#
#
#        posted:
#
#         2024-02-07 14:58
#
#
#
# Listing ID: 7714680123
#
# Title: FREE Woven Jute Green Door Mat Rug (San Francisco)
#
# URL of image: https://images.craigslist.org/00H0H_g8eAfzNUKCl_0CI0t2_600x450.jpg
#
# Description: Woven door mat, 100% jute, green and natural color chevron striped pattern.
#
#
#       Pick up only.
#
# post id: 7714680123
#
#
#        posted:
#
#         2024-02-05 09:28
#
#
#
#        updated:
#
#         2024-02-07 11:11
#
#
#
# Listing ID: 7714559809
#
# Title: Usb camera (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/00J0J_7CzOeLT8S1V_0lM0t2_600x450.jpg
#
# Description: Usb camera
#
#       16th Ave between Geary and Clement
#
# post id: 7714559809
#
#
#        posted:
#
#         2024-02-05 00:40
#
#
#
#        updated:
#
#         2024-02-07 15:34
#
#
#
# Listing ID: 7715458153
#
# Title: Craps Table For Free (San Francisco)
#
# URL of image: https://images.craigslist.org/00p0p_7EAbQ9703dT_0hT0CI_600x450.jpg
#
# Description: I have a vintage craps table in my office space I am trying to get rid of. Must pic up. the legs do unscrew for easy removal. It is up one flight up stairs. Must pick up and take out yourself.
#
# post id: 7715458153
#
#
#        posted:
#
#         2024-02-07 13:10
#
#
#
#        updated:
#
#         2024-02-07 13:10
#
#
#
# Listing ID: 7715447619
#
# Title: FREE desk chair (walnut creek)
#
# URL of image: https://images.craigslist.org/00P0P_2hjvfuPBf6p_0lM0t2_600x450.jpg
#
# Description: FREE Chair with comfortable cushion upholstered in gray woven fabric. Adjustable seat and back, on casters. No animals in residence. 35"H, 27"W, 20"D. Normal wear, no tears or stains. Plan to move chair down two flights of stairs, I'm injured and can't carry anything. FREE
#
# post id: 7715447619
#
#
#        posted:
#
#         2024-02-07 12:44
#
#
#
# Listing ID: 7715440534
#
# Title: File Cabinet - Oak (novato)
#
# URL of image: https://images.craigslist.org/00101_8sfuIuWmvUk_06E0gw_600x450.jpg
#
# Description: Oak file cabinet.
#
#       52 inches tall.
#
#       27 inches deep.
#
#       20 inches across.
#
#       Oak cabinet from old B of A bldg.  One side did not have a wall.  We put a thin piece of plywood on that side.  B of A made them w/o a side b/c they were originally in a room where others were stacked next to them.  This one was on the end unit so it does have one side.
# post id: 7715440534
#
#
#        posted:
#
#         2024-02-07 12:25
#
#
#
# Listing ID: 7715444062
#
# Title: FREE Lazy Boy sectional couch (santa cruz)
#
# URL of image: https://images.craigslist.org/00v0v_5buiJN5y8YZ_0ak07K_600x450.jpg
#
# Description: 10 foot by 8.5 foot.
#
#       Paid about 4500 8 years ago.
#
#       It has 4 power recliners that function correctly.
#
#       It looks like leather but it's not real leather and the finish is wearing off,
#
#       Shound be fine as is or with a cover ever better.
#
#       Bring a truck or trailer.
#
#       Free, first come gets it.
#
#       Need gone asap ordered a new one.
#
#
#
#
#
#       Bedroom, sofa, couch, sleep, recliner,
#
# post id: 7715444062
#
#
#        posted:
#
#         2024-02-07 12:34
#
#
#
#        updated:
#
#         2024-02-07 13:26
#
#
#
# Listing ID: 7715305986
#
# Title: Raft - Rapid Rider (Capitola)
#
# URL of image: https://images.craigslist.org/00202_d6C7XKr0MpW_0CI0t2_600x450.jpg
#
# Description: Tubular raft with cup holders. Performs as well as the name suggests.
#
# post id: 7715305986
#
#
#        posted:
#
#         2024-02-07 07:18
#
#
#
# Listing ID: 7714743061
#
# Title: IBM Electric Letter Font Ball (richmond / seacliff)
#
# URL of image: https://images.craigslist.org/00E0E_1aWRT1j1ic6_0lM0t2_600x450.jpg
#
# Description: IBM Electric Letter Font Ball
#
#       16th Ave between Geary and Clement
#
# post id: 7714743061
#
#
#        posted:
#
#         2024-02-05 11:44
#
#
#
#        updated:
#
#         2024-02-07 15:34
#
#
#
# Listing ID: 7710140691
#
# Title: Office desk (berkeley)
#
# URL of image: https://images.craigslist.org/00A0A_f8gCM4G8gZ2_09A08d_600x450.jpg
#
# Description: rough measurements: 72"W x 26"D x 29"H
#
#       Thermally fused laminate finish fends off scratches and stains
#
#       Open C-Leg design provides loads of legroom
#
# post id: 7710140691
#
#
#        posted:
#
#         2024-01-22 12:02
#
#
#
#        updated:
#
#         2024-02-07 11:23
#
#
#
# Listing ID: 7715516846
#
# Title: Artificial Christmas Tree (hayward / castro valley)
#
# URL of image: https://images.craigslist.org/01313_7eI2erJ9low_0t20CI_600x450.jpg
#
# Description: 7 feet, no light on it.
#
#       Need to pick it up.
#
#       Nothing wrong with it just too high for our house.
#
# post id: 7715516846
#
#
#        posted:
#
#         2024-02-07 16:06
#
#
#
# Listing ID: 7713265862
#
# Title: free stuff (see pics) (Russian Hill)
#
# URL of image: https://images.craigslist.org/00j0j_gUKYL28ifvB_0Cz0t2_600x450.jpg
#
# Description: please see pics.
#
#
#       if you have any questions, just ask.  Must be able to pick in Russian Hill.
#
#
#       Please don't say that you will pick everything up.
#
#
#       Thanks!
#
# post id: 7713265862
#
#
#        posted:
#
#         2024-02-01 00:10
#
#
#
#        updated:
#
#         2024-02-07 15:43
#
#
#
# Listing ID: 7712753370
#
# No title
#
# No image
#
# No description
#
# Post ID: 7712753370
#
#
#
# Listing ID: 7715530759
#
# Title: Round drum table (willow glen / cambrian)
#
# URL of image: https://images.craigslist.org/00k0k_fhQNMg7dxLN_0t20CI_600x450.jpg
#
# Description: For living area.
#
#
#       Please leave name and number if interested.
#
# post id: 7715530759
#
#
#        posted:
#
#         2024-02-07 16:58
#
#
#
# Listing ID: 7715508675
#
# Title: Free binders (San Francisco)
#
# No image
#
# Description: plenty of free binders in black and white colors.
#
#       2 inch, to 4 inches thick. lightly used, some brand new
#
# post id: 7715508675
#
#
#        posted:
#
#         2024-02-07 15:38
#
#
#
# Listing ID: 7714356712
#
# Title: Couch and recliners free,I'll give 50. To take (concord / pleasant hill / martinez)
#
# URL of image: https://images.craigslist.org/00W0W_jckEl765PMM_0CI0t2_600x450.jpg
#
# Description: Living room couch set
#
#       Free 1 electric recliner
#
#       1 manual recliner both great
#
#       Slight damage to chase, can be covered with blanket, free u haul
#
#       Must take all
#
#
#       *!! I'll give you 50. To take
#
#
#       Nine2five 2six7 nine3nine0
#
# post id: 7714356712
#
#
#        posted:
#
#         2024-02-04 09:28
#
#
#
#        updated:
#
#         2024-02-07 10:06
#
#
#
# Listing ID: 7715434602
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715434602
#
#
#
# Listing ID: 7715451702
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715451702
#
#
#
# Listing ID: 7715332769
#
# Title: Curbside alert (Mount Hermon)
#
# URL of image: https://images.craigslist.org/00I0I_gTQAvLfC9r3_0t20CI_600x450.jpg
#
# Description: Free plastic bunny statue, conduit piping, house trim piece, skewers for roasting , and a large pot tray. On the corner against a redwood in Felton by 619 Redwood Dr.
#
# post id: 7715332769
#
#
#        posted:
#
#         2024-02-07 08:26
#
#
#
# Listing ID: 7714221326
#
# Title: Trick scooter / pro scooter (noe valley)
#
# URL of image: https://images.craigslist.org/00d0d_etymQZkOoOd_0MM132_600x450.jpg
#
# Description: fuzion z series I think
#
#
#       has some rattle, works OK
#
# post id: 7714221326
#
#
#        posted:
#
#         2024-02-03 17:19
#
#
#
#        updated:
#
#         2024-02-07 16:34
#
#
#
# Listing ID: 7715471475
#
# Title: Entertainment unit (dublin / pleasanton / livermore)
#
# URL of image: https://images.craigslist.org/00G0G_2Ea7xUkcNa3_0kO0i1_600x450.jpg
#
# Description: Beautiful solid Oak Entertainment Unit with lighted upper area and glass doors/ shelves for curios. We had a 32” flat screen in it both used in bedroom and family room. Size noted on photo
#
# post id: 7715471475
#
#
#        posted:
#
#         2024-02-07 13:45
#
#
#
# Listing ID: 7715527360
#
# Title: gamer chair and ikea 8 cubby shelf (berkeley north / hills)
#
# URL of image: https://images.craigslist.org/00g0g_erte8hgjK83_1320MM_600x450.jpg
#
# Description: Well worn but free- gamer chair and ikea 8 cubby shelf. Shelf would be fine if you spray paint it. gamer chair is fine but one arm is wiggly. Not rained on. Pick up by 2/8 or it goes to the dump. If post is still up items are still available.
#
# post id: 7715527360
#
#
#        posted:
#
#         2024-02-07 16:43
#
#
#
# Listing ID: 7711183528
#
# Title: Hollister - Arborist Woodchips Mulch, Wood, Logs, Rounds (Hollister)
#
# URL of image: https://images.craigslist.org/00q0q_idyYpHMSTUQ_0ww0ii_600x450.jpg
#
# Description: Free Arborist Woodchips, Wood for whatever you want to use it for, and Wood you can cut up/split for firewood.
#
#
#       EVERYTHING is 100% free, with delivery, since 2001, since 2001.
#
# post id: 7711183528
#
#
#        posted:
#
#         2024-01-25 12:26
#
#
#
#        updated:
#
#         2024-02-07 13:30
#
#
#
# Listing ID: 7715540066
#
# Title: Stool with back (potrero hill)
#
# URL of image: https://images.craigslist.org/00i0i_6oIeRVze81X_0lM0t2_600x450.jpg
#
# Description: Dark wood.
#
#
#       We're rejiggering our furnishings and no longer need / want this.
#
# post id: 7715540066
#
#
#        posted:
#
#         2024-02-07 17:32
#
#
#
# Listing ID: 7715396209
#
# No title
#
# No image
#
# No description
#
# Post ID: 7715396209
#
#
#
# Listing ID: 7715546331
#
# Title: Chaise lounge (willow glen / cambrian)
#
# URL of image: https://images.craigslist.org/00A0A_dLKYFSVNzAh_0t20CI_600x450.jpg
#
# Description: Very simple but works!
#
#
#       Leave name and number for address if interested.
#
# post id: 7715546331
#
#
#        posted:
#
#         2024-02-07 18:01
#
#
#
# Listing ID: 7715490231
#
# Title: Queen box spring (Capitola)
#
# URL of image: https://images.craigslist.org/01313_goCF6PUXTkr_0lM0CI_600x450.jpg
#
# Description: Queen sized box spring. Clean hardly used. Call/text/email anytime.
#
# post id: 7715490231
#
#
#        posted:
#
#         2024-02-07 14:39

# %% [markdown]
# ## Part 3: Automating Login on The Old Reader
#
# ### 1. Creating and Verifying a The Old Reader Account
# Account Creation:  Create an account on https://theoldreader.com Links to an external site..  Use an email address and password that you are comfortable sharing with us.
#
# Manual Login Verification: Before automating the login process, ensure you can manually log in to theoldreader.com with your new credentials.  This confirms that your account is active and your credentials are correct.
#
# --- Account has been successfully created and verified.
#
# ### 2. Exploring the Login Mechanism
# Navigate to the login page of https://theoldreader.com Links to an external site.
#
# Use your browser’s developer tools to inspect the page, focusing on the `form` tag involved in the login process.
#
# #### Document all `input` fields within the login form, paying special attention to their name attributes. These fields are crucial for submitting the login request programmatically.
#
# input name="authenticity_token"
#
# input name="user[login]"
#
# input name="user[password]"
#
# input name="commit"
#
#
# ### 3. Analyzing Network Traffic for Login Request
# With the network tab of your browser’s developer tools open, log in to the site again.
#
# #### Identify the network request made when you submit the login form (GET or POST). Explain why this method was chosen.
# This is a POST request because we are sending data to the server. We are sending the data necessary to login to the link. This method was chosen because we are in need to input our login credentials. If we don't have to input anything and just retrieve existing data, it would be a GET request.

# %%
headers = {'User-Agent' : 'Mozilla/5.0'}

url = 'https://theoldreader.com/users/sign_in'
page = requests.get(url, headers)

soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:400,600" rel="stylesheet" type="text/css"/>
#   <!-- Latest compiled and minified JavaScript -->
#   <script src="https://code.jquery.com/jquery.js">
#   </script>
#   <script src="//netdna.bootstrapcdn.com/bootstrap/3.0.1/js/bootstrap.min.js">
#   </script>
#   <link href="https://fonts.googleapis.com/css?family=Source+Code+Pro" rel="stylesheet" type="text/css"/>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,800" rel="stylesheet"/>
#   <link href="//s.theoldreader.com/assets/reader/public-c7869a909c7b119a27fb646003828344.css" media="screen" rel="stylesheet" type="text/css">
#    <link href="//s.theoldreader.com/assets/apple-touch-icon-57x57-86fe1176e14af4907a6fecfe5ca7e3f1.png" rel="apple-touch-icon-precomposed" sizes="57x57">
#     <link href="//s.theoldreader.com/assets/apple-touch-icon-114x114-bae89acc41c93261dd962ea6ade08d22.png" rel="apple-touch-icon-precomposed" sizes="114x114">
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-72x72-f248503edfa3676f8d58af531aff7e88.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-144x144-510415291cae9b46a9ca4ac39815104e.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-60x60-3426eab125af02dea4867aad969752b2.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-120x120-3ab011024abf6fe2cfc9a8bb4523acf2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-76x76-98376acc9def00445bcc4f35550f5af5.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#      <link href="//s.theoldreader.com/assets/apple-touch-icon-152x152-3e21226fd0e2c9d17119cbe5d5805b42.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#      <link href="//s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="icon" sizes="196x196" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-96x96-6c52a26e02fc07430a98ef484a148f2f.png" rel="icon" sizes="96x96" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-32x32-14f0ea359e8c8a5f19e253ff39e89505.png" rel="icon" sizes="32x32" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-16x16-dbff886c76bb71ed112d1fa5d99850d2.png" rel="icon" sizes="16x16" type="image/png"/>
#      <link href="//s.theoldreader.com/assets/favicon-128-19aa7ffa16364aba074472efe4a432d5.png" rel="icon" sizes="128x128" type="image/png"/>
#      <meta content="The Old Reader" name="application-name">
#       <meta content="#FFFFFF" name="msapplication-TileColor">
#        <meta content="//s.theoldreader.com/assets/mstile-144x144-510415291cae9b46a9ca4ac39815104e.png" name="msapplication-TileImage">
#         <meta content="//s.theoldreader.com/assets/mstile-70x70-19aa7ffa16364aba074472efe4a432d5.png" name="msapplication-square70x70logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-150x150-c50a4164ebb6d3c497822664cb7cb284.png" name="msapplication-square150x150logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-310x150-1b07e17c2f6ecf4a4dc2737f0aa2060d.png" name="msapplication-wide310x150logo"/>
#         <meta content="//s.theoldreader.com/assets/mstile-310x310-4bdd40346db4dd8b402ea5642536e1e0.png" name="msapplication-square310x310logo"/>
#         <link color="#ff2400" href="//s.theoldreader.com/assets/website-icon-890cace9fbea886aaaeb94840b916e20.svg" rel="mask-icon"/>
#         <link href="//s.theoldreader.com/assets/favicon-9a70b996deb81293c0b8a361cfe24228.ico" rel="shortcut icon"/>
#         <meta content="167033558637456" property="fb:app_id"/>
#         <meta content="website" property="og:type"/>
#         <meta content="https://theoldreader.com/users/sign_in?User-Agent=Mozilla%2F5.0" property="og:url"/>
#         <meta content="The Old Reader | Sign In" property="og:title"/>
#         <title>
#          The Old Reader | Sign In
#         </title>
#         <meta content="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" property="og:image"/>
#         <link href="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="image_src">
#          <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." property="og:description"/>
#          <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." name="description"/>
#          <meta content="The Old Reader" property="og:site_name"/>
#          <meta content="the old reader, rss, rss reader, rss aggregator" name="keywords"/>
#          <meta content="pk_live_aAbJCQJbM1C5PFdlUQ09yZHh" name="stripe-key"/>
#          <meta content="v60" http-equiv="x-pjax-version"/>
#          <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' s.theoldreader.com www.google-analytics.com www.googleadservices.com fonts.googleapis.com sdk.spritzinc.com js.stripe.com platform.instagram.com platform.twitter.com syndication.twitter.com connect.facebook.net www.google.com www.gstatic.com cdn.syndication.twimg.com d2wy8f7a9ursnm.cloudfront.net cdnjs.cloudflare.com pagead2.googlesyndication.com www.instagram.com tpc.googlesyndication.com contextual.media.net partner.googleadservices.com adservice.google.com;" http-equiv="Content-Security-Policy">
#           <script data-apikey="fbe8565186cf5b4325c66071e7b0aab1" data-appversion="60" src="//d2wy8f7a9ursnm.cloudfront.net/bugsnag-3.min.js">
#           </script>
#           <script type="text/javascript">
#            if (typeof Bugsnag !== "undefined" && Bugsnag !== null) {
#     Bugsnag.releaseStage = "production";
#     Bugsnag.notifyReleaseStages = ['production'];
#   }
#           </script>
#           <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#           <!--[if lt IE 9]>
#   <script src="//html5shim.googlecode.com/svn/trunk/html5.js" type="text/javascript"></script>
# <![endif]-->
#           <meta content="authenticity_token" name="csrf-param"/>
#           <meta content="6JL+UI7logWKvhs54wc9u3GTeGIC1fhhqjz0FYpO7ak=" name="csrf-token"/>
#           <script type="text/javascript">
#            (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-32299218-1', 'auto');
#   ga('send', 'pageview');
#           </script>
#           <script type="text/javascript">
#            /* <![CDATA[ */
#  goog_snippet_vars = function() {
#    var w = window;
#    w.google_conversion_id = 906647471;
#    w.google_conversion_label = "jUCNCNqw414Qr6-psAM";
#    w.google_remarketing_only = false;
#  }
#  // DO NOT CHANGE THE CODE BELOW.
#  goog_report_conversion = function(url) {
#    goog_snippet_vars();
#    window.google_conversion_format = "3";
#    window.google_is_call = true;
#    var opt = new Object();
#    opt.onload_callback = function() {
#    if (typeof(url) != 'undefined') {
#      window.location = url;
#    }
#  }
#  var conv_handler = window['google_trackConversion'];
#  if (typeof(conv_handler) == 'function') {
#    conv_handler(opt);
#  }
# }
# /* ]]> */
#           </script>
#           <script src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#           </script>
#          </meta>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </link>
#    </link>
#   </link>
#  </head>
#  <body>
#   <div class="container-fluid">
#    <div class="row">
#     <div class="col-md-12">
#      <div class="interior-header-background">
#       <div class="rounded_bottom">
#       </div>
#      </div>
#      <div class="row interior">
#       <div class="col-md-12">
#        <div class="devise-form-continer">
#         <h2>
#          Sign In
#         </h2>
#         <form accept-charset="UTF-8" action="/users/sign_in" class="new_user" id="new_user" method="post" role="form">
#          <div style="margin:0;padding:0;display:inline">
#           <input name="utf8" type="hidden" value="✓"/>
#           <input name="authenticity_token" type="hidden" value="6JL+UI7logWKvhs54wc9u3GTeGIC1fhhqjz0FYpO7ak="/>
#          </div>
#          <div class="form-group">
#           <input autocapitalize="off" autocorrect="off" autofocus="autofocus" class="form-control" id="user_login" name="user[login]" placeholder="Username/Email" size="30" spellcheck="false" type="text"/>
#          </div>
#          <div class="form-group">
#           <input class="form-control" id="user_password" name="user[password]" placeholder="Password" size="30" type="password"/>
#          </div>
#          <input class="btn btn-primary btn-block" name="commit" type="submit" value="Sign In"/>
#         </form>
#         <div class="links">
#          <a href="/users/password/new">
#           Forgot password?
#          </a>
#          <br/>
#          <a href="/users/unlock/new">
#           Need unlock instructions?
#          </a>
#          <br/>
#         </div>
#         <hr/>
#         <div class="oauth">
#          <p>
#           <button data-target="#google-broke-modal" data-toggle="modal" id="fake-goog-btn" type="button">
#            Sign in with Google
#           </button>
#           <!-- removing facebook login, this button is the deprication notice vehicle -->
#          </p>
#         </div>
#         <div class="tos">
#          By registering or signing in, you are agreeing to our
#          <a href="/pages/tos" rel="noopener noreferrer" target="_blank">
#           Terms Of Service
#          </a>
#          and
#          <a href="/pages/privacy" rel="noopener noreferrer" target="_blank">
#           Privacy Policy
#          </a>
#         </div>
#        </div>
#        <hr/>
#       </div>
#      </div>
#      <div class="row footer">
#       <div class="col-md-12">
#        <div class="row">
#         <div class="col-md-2">
#          <a class="footer-icon hidden-sm hidden-xs" href="/home">
#          </a>
#         </div>
#         <div class="col-md-10 nav-links">
#          <p>
#           <a href="/users/sign_up">
#            Sign Up
#           </a>
#          </p>
#          <p>
#           <a href="/users/sign_in">
#            Sign In
#           </a>
#          </p>
#          <p>
#           <a href="/pages/tour">
#            Product Tour
#           </a>
#          </p>
#          <p>
#           <a href="/pages/apps">
#            Apps
#           </a>
#          </p>
#          <p>
#           <a href="/pages/contact">
#            Contact Us
#           </a>
#          </p>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-md-6">
#          <a href="https://twitter.com/theoldreader">
#           <i class="fa fa-twitter">
#           </i>
#           Twitter
#          </a>
#          <a href="https://www.facebook.com/theoldreader">
#           <i class="fa fa-facebook-square">
#           </i>
#           Facebook
#          </a>
#          <a href="http://blog.theoldreader.com">
#           <i class="fa fa-rss">
#           </i>
#           Blog
#          </a>
#         </div>
#         <div class="col-md-6 terms-text">
#          <a href="/pages/privacy">
#           Privacy policy
#          </a>
#          |
#          <a href="/pages/tos">
#           Terms of Service
#          </a>
#          © 2012-2024 The Old Reader
#         </div>
#        </div>
#       </div>
#      </div>
#      <script src="//s.theoldreader.com/assets/public-5f12d594e3f83bcc960d62452ce6c1c7.js" type="text/javascript">
#      </script>
#     </div>
#    </div>
#   </div>
#   <div class="header-scrolled show">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-md-12">
#       <div class="header clearfix">
#        <a class="logo" href="/home">
#        </a>
#        <div class="sign-up hidden-sm hidden-xs">
#         <a href="/users/sign_up">
#          Sign Up
#         </a>
#         <div class="vertical-line">
#          <div>
#          </div>
#         </div>
#         <a href="/users/sign_in" onclick="ga('send', 'event', 'Login Header', 'click')">
#          Sign In
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#   </script>
#  </body>
#  <div aria-hidden="true" aria-labelledby="#fb-deprication-modal" class="modal fade" id="fb-deprication-modal" role="dialog" tabindex="-1">
#   <div class="modal-dialog" role="document">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#       ×
#      </button>
#     </div>
#     <div class="modal-body">
#      <p id="fb-deprication-notice">
#       Due to continued changes with Facebook login and concerns about privacy with Facebook, we've decided to stop supporting Facebook login. It's easy to transition your account by using the
#       <a href="/users/password/new">
#        Forgot password?
#       </a>
#       link and entering the email address associated with your Facebook account. Then you can set a password and login directly to The Old Reader. Thanks for your understanding and thanks for continuing to use The Old Reader.
#      </p>
#     </div>
#     <div class="modal-footer">
#      <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#  </div>
#  <div aria-hidden="true" aria-labelledby="#google-broke-modal" class="modal fade" id="google-broke-modal" role="dialog" tabindex="-1">
#   <div class="modal-dialog" role="document">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#       ×
#      </button>
#     </div>
#     <div class="modal-body">
#      <p id="fb-deprication-notice">
#       Google Sign In is not currently working due to an issue with our host. It's easy to login to your account by using the
#       <a href="/users/password/new">
#        Forgot password?
#       </a>
#       link and entering the email address associated with your google account. Then you can set a password and login directly to The Old Reader. We will remove this message when the issue is resolved and you will be able to resume logging in using Google Sign In. Thanks for your understanding and thanks for continuing to use The Old Reader.
#      </p>
#     </div>
#     <div class="modal-footer">
#      <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#       Close
#      </button>
#     </div>
#    </div>
#   </div>
#  </div>
#  <script>
#   $('#fake-fb-btn').on('click',function() {
#       $('#fb-deprication-notice').modal('show')
#     })
#     $('#fake-goog-btn').on('click',function() {
#       $('#google-broke-modal').modal('show')
#     })
#  </script>
# </html>

# %%
form = soup.select_one('#new_user')

auth_input = form.select_one('input[name=authenticity_token]')
auth = auth_input.get('value')

print(auth)
# Out:
# 6JL+UI7logWKvhs54wc9u3GTeGIC1fhhqjz0FYpO7ak=

# %% [markdown]
# #### Carefully examine the payload that was submitted to the server during login. Compare this payload to the `form` / `input` fields you previously analyzed. Explain your observation.
# We can see that the payload has all the fields that we identified in the input tags. Here, we copy the values in the payload for 'user[login]', 'user[password]' and 'commit' and input it in the session.post(data=) code.
#
# For the authenticity token, since it could be dynamic we are going to input the 'auth' variable from the previous line of code.

# %% [markdown]
# ### 4. Automating the Login Process
# Using Python and appropriate libraries like requests, simulate the login process.
#
# Create a session object to maintain your login state across multiple requests.
#
# Prepare a payload with your login credentials and other necessary form data identified from the login page and the network analysis.
#
# Send a POST request to the login form’s action URL to log in, using the session object.

# %%
time.sleep(5)

session = requests.session()

session.post("https://theoldreader.com/users/sign_in", data = {'authenticity_token' : auth,
                                                              'user[login]' : 'sujaidt98@gmail.com',
                                                              'user[password]' : 'thesecret',
                                                               'commit' : 'Sign In'},
                                                              timeout=20)
cookies = session.cookies.get_dict()
print(cookies)
# Out:
# {'_new_reader_session': '%3D%3D--3b3b523387b5a77bad630f5d16d7a6e32630572b', 'i_know_you': 'Sujai+Adithya', 'remember_user_token': 'BAhbB1sGVToaTW9wZWQ6OkJTT046Ok9iamVjdElkIhFlZcgQlu3sVJM4wg5JIiIkMmEkMDUkN0ZsNXhZLlgxOWx3Yk1wWEd5eng3TwY6BkVU--febd6901858f7066c59d3947cdf18878a87370c7', 'signed_at': '1707414622'}

# %% [markdown]
# ### 5. Verifying Successful Login
# After attempting to log in, inspect the cookies saved in the session object to understand the information The Old Reader stores on your computer.
#
# Use the session object to access https://theoldreader.com Links to an external site..
#
# Verify successful login by checking for the presence of your user information that is only available when logged in.

# %%
time.sleep(5)

url2 = 'https://theoldreader.com'
page2 = session.get(url2, cookies=cookies)

soup2 = BeautifulSoup(page2.content, 'html.parser')
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
#   <link href="//s.theoldreader.com/assets/application-befb06d5a14978388154b51422cef437.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-57x57-86fe1176e14af4907a6fecfe5ca7e3f1.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-114x114-bae89acc41c93261dd962ea6ade08d22.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-72x72-f248503edfa3676f8d58af531aff7e88.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-144x144-510415291cae9b46a9ca4ac39815104e.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-60x60-3426eab125af02dea4867aad969752b2.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-120x120-3ab011024abf6fe2cfc9a8bb4523acf2.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-76x76-98376acc9def00445bcc4f35550f5af5.png" rel="apple-touch-icon-precomposed" sizes="76x76"/>
#   <link href="//s.theoldreader.com/assets/apple-touch-icon-152x152-3e21226fd0e2c9d17119cbe5d5805b42.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="icon" sizes="196x196" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-96x96-6c52a26e02fc07430a98ef484a148f2f.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-32x32-14f0ea359e8c8a5f19e253ff39e89505.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-16x16-dbff886c76bb71ed112d1fa5d99850d2.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="//s.theoldreader.com/assets/favicon-128-19aa7ffa16364aba074472efe4a432d5.png" rel="icon" sizes="128x128" type="image/png"/>
#   <meta content="The Old Reader" name="application-name">
#    <meta content="#FFFFFF" name="msapplication-TileColor">
#     <meta content="//s.theoldreader.com/assets/mstile-144x144-510415291cae9b46a9ca4ac39815104e.png" name="msapplication-TileImage">
#      <meta content="//s.theoldreader.com/assets/mstile-70x70-19aa7ffa16364aba074472efe4a432d5.png" name="msapplication-square70x70logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-150x150-c50a4164ebb6d3c497822664cb7cb284.png" name="msapplication-square150x150logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-310x150-1b07e17c2f6ecf4a4dc2737f0aa2060d.png" name="msapplication-wide310x150logo"/>
#      <meta content="//s.theoldreader.com/assets/mstile-310x310-4bdd40346db4dd8b402ea5642536e1e0.png" name="msapplication-square310x310logo"/>
#      <link color="#ff2400" href="//s.theoldreader.com/assets/website-icon-890cace9fbea886aaaeb94840b916e20.svg" rel="mask-icon"/>
#      <link href="//s.theoldreader.com/assets/favicon-9a70b996deb81293c0b8a361cfe24228.ico" rel="shortcut icon"/>
#      <meta content="167033558637456" property="fb:app_id"/>
#      <meta content="website" property="og:type"/>
#      <meta content="https://theoldreader.com/" property="og:url"/>
#      <meta content="The Old Reader" property="og:title"/>
#      <meta content="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" property="og:image"/>
#      <link href="https://s.theoldreader.com/assets/favicon-196x196-b2a8c74975d8498591dd629b89797dea.png" rel="image_src">
#       <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." property="og:description"/>
#       <meta content="Read all your favorite online content in one place. Import your subscriptions in one click, find your friends, and start sharing." name="description"/>
#       <meta content="The Old Reader" property="og:site_name"/>
#       <meta content="the old reader, rss, rss reader, rss aggregator" name="keywords"/>
#       <meta content="pk_live_aAbJCQJbM1C5PFdlUQ09yZHh" name="stripe-key"/>
#       <meta content="v60" http-equiv="x-pjax-version"/>
#       <meta content="script-src 'self' 'unsafe-inline' 'unsafe-eval' s.theoldreader.com www.google-analytics.com www.googleadservices.com fonts.googleapis.com sdk.spritzinc.com js.stripe.com platform.instagram.com platform.twitter.com syndication.twitter.com connect.facebook.net www.google.com www.gstatic.com cdn.syndication.twimg.com d2wy8f7a9ursnm.cloudfront.net cdnjs.cloudflare.com pagead2.googlesyndication.com www.instagram.com tpc.googlesyndication.com contextual.media.net partner.googleadservices.com adservice.google.com;" http-equiv="Content-Security-Policy">
#        <script data-apikey="fbe8565186cf5b4325c66071e7b0aab1" data-appversion="60" src="//d2wy8f7a9ursnm.cloudfront.net/bugsnag-3.min.js">
#        </script>
#        <script type="text/javascript">
#         if (typeof Bugsnag !== "undefined" && Bugsnag !== null) {
#     Bugsnag.releaseStage = "production";
#     Bugsnag.notifyReleaseStages = ['production'];
#     Bugsnag.user = {
#       id: "6565c81096edec549338c20e",
#       name: "Sujai Adithya",
#       email: "sujaidt98@gmail.com"
#     }
#   }
#        </script>
#        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#        <!--[if lt IE 9]>
#   <script src="//html5shim.googlecode.com/svn/trunk/html5.js" type="text/javascript"></script>
# <![endif]-->
#        <meta content="authenticity_token" name="csrf-param"/>
#        <meta content="kXLgu9BxqtF56C/H3UeGKsrVwwPh43LHs5i3iJ8p9nI=" name="csrf-token"/>
#        <script type="text/javascript">
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-32299218-1', 'auto');
#   ga('send', 'pageview');
#        </script>
#        <script type="text/javascript">
#         /* <![CDATA[ */
#  goog_snippet_vars = function() {
#    var w = window;
#    w.google_conversion_id = 906647471;
#    w.google_conversion_label = "jUCNCNqw414Qr6-psAM";
#    w.google_remarketing_only = false;
#  }
#  // DO NOT CHANGE THE CODE BELOW.
#  goog_report_conversion = function(url) {
#    goog_snippet_vars();
#    window.google_conversion_format = "3";
#    window.google_is_call = true;
#    var opt = new Object();
#    opt.onload_callback = function() {
#    if (typeof(url) != 'undefined') {
#      window.location = url;
#    }
#  }
#  var conv_handler = window['google_trackConversion'];
#  if (typeof(conv_handler) == 'function') {
#    conv_handler(opt);
#  }
# }
# /* ]]> */
#        </script>
#        <script src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#        </script>
#        <title data-bind="text: title">
#         The Old Reader
#        </title>
#        <script type="text/javascript">
#         var FEEDS = {
#     feeds: [{"position":null,"id":null,"subscriptions":[],"title":null,"destroyed":null},{"position":1,"id":"65c3f810fea0e76c300001b7","subscriptions":[{"feed_id":"aed846f0d597789927a7ce68","folder_id":"65c3f810fea0e76c300001b7","position":1,"id":"65c3f810fea0e76c300001bb","icon":"/system/uploads/feed/picture/aed8/46f0/d597/7899/27a7/icon_ce68.ico","url":"https://www.apartmenttherapy.com/main.rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"Apartment Therapy| Saving the world, one room at a time","unread_count":25,"destroyed":null},{"feed_id":"ded4c2c4abc703638c0a2a79","folder_id":"65c3f810fea0e76c300001b7","position":2,"id":"65c3f819fea0e76c300001c9","icon":"/system/uploads/feed/picture/ded4/c2c4/abc7/0363/8c0a/icon_2a79.ico","url":"https://www.getrichslowly.org/feed/","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"Get Rich Slowly","unread_count":10,"destroyed":null},{"feed_id":"514d5f3d54cf82eed0004675","folder_id":"65c3f810fea0e76c300001b7","position":3,"id":"65c3f81dfea0e76c300001d7","icon":"/system/uploads/feed/picture/514d/5f3d/54cf/82ee/d000/icon_4675.ico","url":"https://what-if.xkcd.com/feed.atom","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"what if?","unread_count":5,"destroyed":null},{"feed_id":"50e2ea09bd927918880000a7","folder_id":"65c3f810fea0e76c300001b7","position":4,"id":"65c3f822fea0e76c300001e0","icon":"/system/uploads/feed/picture/50e2/ea09/bd92/7918/8800/icon_00a7.ico","url":"http://blog.theoldreader.com/rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"The Old Reader: behind the scenes","unread_count":10,"destroyed":null},{"feed_id":"514e224954cf822997011be6","folder_id":"65c3f810fea0e76c300001b7","position":5,"id":"65c3f82afea0e76c300001f1","icon":"/system/uploads/feed/picture/514e/2249/54cf/8229/9701/icon_1be6.ico","url":"https://thedailywhat.cheezburger.com/rss","share_count":null,"star_count":null,"comment_count":null,"sendto_count":null,"title_click_count":null,"body_link_click_count":null,"mark_all_as_read_count":null,"likes_count":null,"title":"The Daily What","unread_count":10,"destroyed":null}],"title":"The Old Reader Picks","destroyed":null}],
#     following: [],
#     comments: 0,
#     new_suggested: false
#   };
#   var SETTINGS = {"destroyed":false,"show_all":true,"show_list":false,"show_reverse":false,"notify_followed":true,"click_to_scroll":false,"scroll_to_read":"full","sidebar_unread_only":false,"sidebar_alpha":false,"share_timeline":false,"show_fb_profile":true,"locale":null,"use_spritz":false,"dont_email_news_updates":false,"dont_email_recs":false,"dismissed_paid_message":true,"confirm_read_all":false,"private_mode":false,"dark_theme":false,"font_size":13};
#   var SENDTOS = [{"_id":"65c5157ffea0e7224800035b","is_enabled":true,"provider":"mailto","title":"Email","url":"mailto:?subject=%{title}\u0026body=%{url}%0D%0A%0D%0A%28via%20theoldreader.com%29"},{"_id":"65c5157ffea0e7224800035c","is_enabled":true,"provider":"facebook","title":"Facebook","url":"https://www.facebook.com/dialog/share?app_id=167033558637456\u0026display=popup\u0026redirect_uri=http%3A%2F%2Ftheoldreader.com%2Ffacebook_callback.html\u0026href=%{url}"},{"_id":"65c5157ffea0e7224800035d","is_enabled":true,"provider":"twitter","title":"Twitter","url":"https://twitter.com/intent/tweet?url=%{url}\u0026text=%{title}\u0026via=theoldreader"}]
#   var USERINFO = {"id":"6565c81096edec549338c20e","display_name":"Sujai Adithya","icon_url":"//s.theoldreader.com/icons/user_icon.png","profile_url":"https://theoldreader.com/posts/profile/6565c81096edec549338c20e"}
#        </script>
#        <script type="text/javascript">
#         window._mNHandle = window._mNHandle || {};
#     window._mNHandle.queue = window._mNHandle.queue || [];
#     medianet_versionId = "3121199";
#        </script>
#        <script async="async" src="https://contextual.media.net/dmedianet.js?cid=8CUB6WHOQ">
#        </script>
#       </meta>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="theme-status reader fixed-header" data-behavior="reader" data-dark-theme="false">
#   <!-- find me in shared/header -->
#   <nav class="navbar navbar-default navbar-fixed-top">
#    <div class="container-fluid">
#     <div class="row">
#      <div class="col-md-3">
#       <!-- Brand and toggle get grouped for better mobile display -->
#       <div class="navbar-header">
#        <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar-collapse" data-toggle="collapse" type="button">
#         <span class="sr-only">
#          Toggle navigation
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#         <span class="icon-bar">
#         </span>
#        </button>
#        <a class="brand" data-pjax="" href="/">
#        </a>
#       </div>
#      </div>
#      <div class="col-md-9">
#       <!-- Collect the nav links, forms, and other content for toggling -->
#       <div class="collapse navbar-collapse" id="navbar-collapse">
#        <form action="/posts/search/%query%" class="navbar-form form-search navbar-left hidden-sm hidden-xs" role="search">
#         <div class="form-group">
#          <input class="form-control search-query" id="search-box" placeholder="Search" title="Search Terms" type="text" value=""/>
#         </div>
#         <button class="btn" type="submit">
#         </button>
#        </form>
#        <ul class="nav navbar-nav navbar-right">
#         <li class="visible-lg-inline">
#          <a class="buy-now" href="https://theoldreader.com/accounts/manage" title="More of a great thing with The Old Reader Premium">
#           Upgrade To Premium
#           <i class="fa fa-rocket">
#           </i>
#          </a>
#         </li>
#         <li class="hidden-lg">
#          <a class="buy-now" href="https://theoldreader.com/accounts/manage" title="More of a great thing with The Old Reader Premium">
#           Upgrade
#           <i class="fa fa-rocket">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social" data-pjax="" href="/profile/friends">
#           Find Friends
#          </a>
#         </li>
#         <li>
#          <a data-pjax="" href="/feeds/import">
#           Import
#          </a>
#         </li>
#         <li class="hidden-xs">
#          <a href="mailto:support@theoldreader.com" title="Need Help?">
#           <i class="fa fa-lg fa-question-circle">
#           </i>
#          </a>
#         </li>
#         <li class="hidden-md hidden-lg">
#          <a data-pjax="" href="/posts/search">
#           Search
#          </a>
#         </li>
#         <li class="dropdown">
#          <a class="dropdown-toggle" data-hover="dropdown" data-toggle="dropdown" href="#" title="Sujai Adithya">
#           Sujai Adithya
#           <i class="fa fa-caret-down">
#           </i>
#          </a>
#          <ul class="dropdown-menu">
#           <li class="dropdown-header">
#            Settings
#           </li>
#           <li>
#            <a data-pjax="" href="/users/edit">
#             Manage Settings
#            </a>
#           </li>
#           <li>
#            <a href="https://theoldreader.com/accounts/manage">
#             Manage Account
#            </a>
#           </li>
#           <li>
#            <a data-pjax="" href="/subscriptions">
#             Manage Subscriptions
#            </a>
#           </li>
#           <li>
#            <a data-pjax="" href="/profile/6565c81096edec549338c20e">
#             View Profile
#            </a>
#           </li>
#           <li class="divider">
#           </li>
#           <li class="dropdown-header">
#            Help
#           </li>
#           <li>
#            <a data-pjax="" href="/pages/tour">
#             Product Tour
#            </a>
#           </li>
#           <li>
#            <a href="mailto:support@theoldreader.com">
#             Support
#            </a>
#           </li>
#           <li class="divider">
#           </li>
#           <li>
#            <a href="/users/sign_out">
#             Sign Out
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </div>
#   </nav>
#   <div class="main-container">
#    <div class="main-row">
#     <div class="cell sidenav-cell">
#      <div class="subscribe-button-container">
#       <div class="bg">
#       </div>
#       <div class="subscribe" id="subscribe">
#        <a class="btn btn-primary btn-lg dropdown-toggle" href="#subscribe">
#         <span class="add-icon hidden-sm hidden-xs">
#         </span>
#         Add a subscription
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <form accept-charset="UTF-8" action="/feeds" class="form-inline" method="post">
#           <div style="margin:0;padding:0;display:inline">
#            <input name="utf8" type="hidden" value="✓">
#             <input name="authenticity_token" type="hidden" value="kXLgu9BxqtF56C/H3UeGKsrVwwPh43LHs5i3iJ8p9nI="/>
#            </input>
#           </div>
#           <div class="control-group">
#            <table>
#             <tr>
#              <td>
#               <input class="col-md-2" id="new-feed-url" name="feed[url]" placeholder="Keyword or Feed URL" type="text"/>
#              </td>
#              <td style="width: 60px;">
#               <button class="btn btn-default" type="submit">
#                <img alt="Ico-plus" src="//s.theoldreader.com/assets/ico-plus-369f50fa00968793b3c2e814f3e55de5.png"/>
#                <i class="fa fa-spinner fa-spin" style="display:none;">
#                </i>
#               </button>
#              </td>
#             </tr>
#            </table>
#            <div class="help-block">
#            </div>
#           </div>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="nano banner_user" id="sidebar">
#       <div class="slide">
#        <div class="well sidebar-nav">
#         <ul class="nav sidebar-nav-list nav-list">
#          <li class="" data-bind="css: { active: '/' == Reader.View().path() }" id="sidebar-home">
#           <a data-pjax="" data-shortcut="g-h" href="/" title="Home">
#            <i class="fa fa-home">
#            </i>
#            Home
#           </a>
#          </li>
#          <li class="" data-bind="css: { active: '/posts/all' == Reader.View().path() }" id="unread_count">
#           <a data-pjax="" data-shortcut="g-a" href="/posts/all" title="All items">
#            <i class="fa fa-list">
#            </i>
#            All items
#            <span class="hidden badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#            </span>
#           </a>
#          </li>
#          <li class="" data-bind="css: { active: '/posts/starred' == Reader.View().path() }" id="sidebar-starred">
#           <a data-pjax="" data-shortcut="g-f" href="/posts/starred" title="Starred">
#            <i class="fa fa-star">
#            </i>
#            Starred
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/posts/liked' == Reader.View().path() }" id="sidebar-liked">
#           <a data-pjax="" data-shortcut="g-l" href="/posts/liked" title="Liked">
#            <i class="fa fa-heart">
#            </i>
#            Liked
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/profile/6565c81096edec549338c20e' == Reader.View().path() }" id="sidebar-shared">
#           <a data-pjax="" data-shortcut="g-s" href="/profile/6565c81096edec549338c20e" title="Shared">
#            <i class="fa fa-share">
#            </i>
#            Shared
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/bookmarks' == Reader.View().path() }" id="sidebar-bookmarked">
#           <a data-pjax="" data-shortcut="g-b" href="/bookmarks" title="Bookmarked">
#            <i class="fa fa-bookmark">
#            </i>
#            Bookmarked
#           </a>
#          </li>
#          <li class="social" data-bind="css: { active: '/posts/trending' == Reader.View().path() }" id="sidebar-trending">
#           <a data-pjax="" data-shortcut="g-t" href="/posts/trending" title="Trending">
#            <i class="fa fa-signal">
#            </i>
#            Trending
#           </a>
#          </li>
#          <li class="social hidden" data-bind="css: { active: '/posts/commented' == Reader.View().path(), hidden: comments_count() == 0 }" id="comments_count">
#           <a data-pjax="" data-shortcut="g-c" href="/posts/commented" title="Commented">
#            <i class="fa fa-comment">
#            </i>
#            Commented
#            <span class="hidden badge badge-info" data-bind="text: comments_count, css: { hidden: comments_count() == 0 }">
#            </span>
#           </a>
#          </li>
#         </ul>
#         <div class="hidden" data-bind="css: { hidden: following().length == 0, hidden_: following_unread_count() == 0 }" id="sidebar-following">
#          <ul class="nav nav-list">
#           <li class="nav-header dropdown" data-bind="css: { active: '/posts/following' == Reader.View().path() }" data-nav-item="">
#            <a class="fa" data-bind="css: { 'fa-chevron-down': !$.cookie('following_hidden'), 'fa-chevron-right': $.cookie('following_hidden') }" data-nav-collapse="" for="following" href="#">
#            </a>
#            <a data-pjax="" data-shortcut="g-p" href="/posts/following" id="following_title" title="Following">
#             <span>
#              Following
#             </span>
#             <span class="badge" data-bind="text: following_unread_count, css: { hidden: following_unread_count() == 0 }">
#             </span>
#            </a>
#           </li>
#          </ul>
#          <ul class="nav nav-list following-list" data-bind="foreach: following, sortableList: { sortList: null, container: 'following-list' }, css: { collapsed: $.cookie('following_hidden') }" id="following">
#           <li class="sort-item social" data-bind="sortableItem: { item: $data, parentList: null }, attr: { id: dom_id }, css: { active: link == Reader.View().path(), hidden_: unread_count() == 0 }" data-nav-item="">
#            <a data-bind="attr: { href: link, title: title }" data-pjax="">
#             <i class="favicon" data-bind="style: { backgroundImage: 'url(' + icon() + ')' }">
#             </i>
#             <strong data-bind="text: title">
#             </strong>
#             <span class="badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="hidden folders-list" data-bind="foreach: folders, sortableList: { sortList: null, container: 'folders-list' }, css: { hidden: feeds_count() == 0 }">
#          <div class="sort-item" data-bind="sortableItem: { item: $data, parentList: null }, css: { prevent: id == null }">
#           <ul class="nav nav-list" data-bind="css: { hidden: (id == null &amp;&amp; feeds().length == 0) || (SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; !contains_feed(Reader.View().feed_id) &amp;&amp; link != Reader.View().path()) }">
#            <li class="nav-header dropdown" data-bind="attr: { id: dom_id + '_title' }, css: { editing: editing, active: link == Reader.View().path() }" data-nav-item="">
#             <a class="fa" data-bind="attr: { for: dom_id }, css: { 'fa-chevron-down': !hidden, 'fa-chevron-right': hidden }" data-nav-collapse="" href="#">
#             </a>
#             <a data-bind="attr: { href: link, title: title }, event: { click: click }" data-pjax="">
#              <span data-bind="text: title">
#              </span>
#              <span class="badge" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#              </span>
#             </a>
#             <input class="form-control" data-bind="attr: { value: title }, event: { blur: stop, keyup: keyup }" type="text"/>
#            </li>
#           </ul>
#           <ul class="nav nav-list feeds-list" data-bind="foreach: feeds, sortableList: { sortList: id, showOnStart: '.new-folder', container: 'feeds-list' }, attr: { id: dom_id }, css: { hidden: (id == null &amp;&amp; feeds().length == 0) || (SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; !contains_feed(Reader.View().feed_id) &amp;&amp; link != Reader.View().path()), collapsed: hidden } ">
#            <li class="sort-item" data-bind="sortableItem: { item: $data, parentList: folder_id }, attr: { id: dom_id }, css: { active: link == Reader.View().path(), editing: editing, hidden: SETTINGS.sidebar_unread_only == true &amp;&amp; unread_count() == 0 &amp;&amp; link != Reader.View().path() }" data-nav-item="">
#             <a data-bind="attr: { href: link, title: title }, event: { click: click } " data-pjax="">
#              <i class="favicon" data-bind="style: { backgroundImage: 'url(' + icon() + ')' }">
#              </i>
#              <strong data-bind="text: title">
#              </strong>
#              <span class="badge badge-info" data-bind="text: unread_count, css: { hidden: unread_count() == 0 }">
#              </span>
#             </a>
#             <input class="form-control" data-bind="attr: { value: title }, event: { blur: stop, keyup: keyup }" type="text"/>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <ul class="hidden nav nav-list new-folder">
#          <li class="nav-header dropdown">
#           <i class="fa fa-chevron-down">
#           </i>
#           <span>
#            New folder
#           </span>
#          </li>
#         </ul>
#         <ul class="hidden nav nav-list feeds-list new-folder sortable-clear" data-bind="sortableList: { sortList: -1, container: 'feeds-list' }">
#          <li class="prevent">
#           <em>
#            Drop here to add a new folder
#           </em>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="banner" id="banner_container" style="height: 275px;">
#       <div class="banner-inner" style="padding:0;">
#        <div class="ad-wrap-tor" id="tor-ad-wrapper">
#         <a class="close" href="#" id="close_banner">
#          <i class="fa fa-times">
#          </i>
#         </a>
#         <div id="ad-container">
#          <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#          </script>
#          <!-- Fixed size Ad -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-8488747604526930" data-ad-slot="7598282246" style="display:inline-block;width:199px;height:275px">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#         <div class="hide-ad-tor" id="premium-ad-container">
#          <div class="premium-ad-inner">
#           <!-- <a href="#" class="close" id="close_prem_banner"><i class="fa fa-times"></i></a> -->
#           <h3 class="premium-ad-heading">
#            Don't like ads?
#           </h3>
#           <p class="premium-ad-text">
#            We don't either. With The Old Reader Premium, you'll never see an ad again.
#           </p>
#           <a class="premium-ad-btn" data-method="post" href="/accounts/start_trial?from_feed=true" rel="nofollow">
#            START FREE TRIAL
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="cell content-cell body-fixed-top">
#      <div class="nano" data-behavior="contents">
#       <div class="loader">
#       </div>
#       <div class="slide">
#        <div class="row home-page">
#         <div class="col-md-7">
#          <div class="row hidden">
#           <div class="col-md-12">
#            <div class="sponsorship">
#             <a data-pjax="true" href="/sponsorships">
#              <img alt="The Old Reader Icon" src="//s.theoldreader.com/assets/apple-touch-icon-72x72-f248503edfa3676f8d58af531aff7e88.png"/>
#              Sponsorship opportunities are now available.  Learn more.
#             </a>
#             <a class="close" href="#">
#              ×
#             </a>
#            </div>
#           </div>
#          </div>
#          <div class="row">
#           <div class="col-md-12">
#            <h3>
#             You have
#             <em>
#              60
#             </em>
#             unread posts
#            </h3>
#            <dl class="dl-horizontal">
#             <dt>
#              <a class="label label-feed" data-pjax="" data-replace="feedTitleByFeedId('aed846f0d597789927a7ce68','www.apartmenttherapy.com')" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '', 'https://www.apartmenttherapy.com/how-to-clean-a-tv-screen-37372242?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#               ...
#              </a>
#             </dt>
#             <dd>
#              <p>
#               <strong dir="ltr">
#                <a data-pjax="" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '?include%5B%5D=65c50314ca9f401a5900af01', 'https://www.apartmenttherapy.com/how-to-clean-a-tv-screen-37372242?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#                 The Right Way to Clean Your TV Screen
#                </a>
#               </strong>
#               <br/>
#               <small data-hover-time="1707408000" data-time="1707410045" data-title-time="1707408000">
#                08 Feb 16:34
#               </small>
#               <br/>
#               <div dir="ltr">
#                Learn how to get it clean without damaging it.
# READ MORE...
#               </div>
#              </p>
#             </dd>
#             <dt>
#              <a class="label label-feed" data-pjax="" data-replace="feedTitleByFeedId('aed846f0d597789927a7ce68','www.apartmenttherapy.com')" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '', 'https://www.apartmenttherapy.com/target-seed-planting-kits-37372826?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#               ...
#              </a>
#             </dt>
#             <dd>
#              <p>
#               <strong dir="ltr">
#                <a data-pjax="" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '?include%5B%5D=65c50314ca9f401a5900af02', 'https://www.apartmenttherapy.com/target-seed-planting-kits-37372826?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#                 Target’s “Super Cute” $13 Seed Kits Are Perfect for Spring
#                </a>
#               </strong>
#               <br/>
#               <small data-hover-time="1707407100" data-time="1707410044" data-title-time="1707407100">
#                08 Feb 16:34
#               </small>
#               <br/>
#               <div dir="ltr">
#                From pizza herbs, to tea gardens, and more.
# READ MORE...
#               </div>
#              </p>
#             </dd>
#             <dt>
#              <a class="label label-feed" data-pjax="" data-replace="feedTitleByFeedId('aed846f0d597789927a7ce68','www.apartmenttherapy.com')" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '', 'https://www.apartmenttherapy.com/kitchen-makeover-green-wallpaper-130-dollars-ba-37372188?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#               ...
#              </a>
#             </dt>
#             <dd>
#              <p>
#               <strong dir="ltr">
#                <a data-pjax="" data-replace-href="feedHrefByFeedId('aed846f0d597789927a7ce68', '?include%5B%5D=65c460885f45b7a3d90169dd', 'https://www.apartmenttherapy.com/kitchen-makeover-green-wallpaper-130-dollars-ba-37372188?utm_source=RSS&amp;utm_medium=feed&amp;utm_campaign=Category%2FChannel%3A+main')" href="/feeds/aed846f0d597789927a7ce68/view">
#                 See How This “Bland” ‘90s Kitchen Got a Forest-Glam Redo (for $130!)
#                </a>
#               </strong>
#               <br/>
#               <small data-hover-time="1707346800" data-time="1707368232" data-title-time="1707346800">
#                08 Feb 04:57
#               </small>
#               <br/>
#               <div dir="ltr">
#                Three DIY projects transform the space.
# READ MORE...
#               </div>
#              </p>
#             </dd>
#            </dl>
#            <h3>
#             News from The Old Reader
#            </h3>
#            <dl class="dl-horizontal announcements">
#             <dt>
#              <div class="label label-default">
#               Secure browsing
#              </div>
#             </dt>
#             <dd>
#              <p>
#               Secure browsing over https is now enabled by default. You can change this in your
#               <a href="/users/edit">
#                settings
#               </a>
#               .
#              </p>
#             </dd>
#             <dt>
#              <div class="label label-default">
#               Reeder Support
#              </div>
#             </dt>
#             <dd>
#              <p>
#               The extremely popular and beautifully designed iOS and Mac RSS app
#               <a href="http://reederapp.com" rel="noopener noreferrer" target="_blank">
#                Reeder
#               </a>
#               just released support for The Old Reader.
#              </p>
#             </dd>
#             <dt>
#              <div class="label label-default">
#               Bookmarklet
#              </div>
#             </dt>
#             <dd>
#              <p>
#               Premium users can now send any page on the web into The Old Reader. Visit your
#               <a href="/bookmarks">
#                bookmarks page
#               </a>
#               for more info.
#              </p>
#             </dd>
#            </dl>
#           </div>
#          </div>
#         </div>
#         <div class="col-md-5">
#          <div class="relations-info">
#           <h3>
#            Your profile
#           </h3>
#           <div class="btns">
#            <a class="label label-social" data-pjax="" href="/profile/6565c81096edec549338c20e/following">
#             <strong>
#              0
#             </strong>
#             Following
#            </a>
#            <a class="label label-social" data-pjax="" href="/profile/6565c81096edec549338c20e/followers">
#             <strong>
#              0
#             </strong>
#             Followers
#            </a>
#           </div>
#          </div>
#          <div class="clearfix">
#          </div>
#          <h3>
#           Recently updated
#          </h3>
#          <dl class="updated dl-horizontal">
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f810fea0e76c300001bb">
#             Apartment Therapy| Saving the world, one room at a time
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1707410045" data-title-time="1707410045">
#              08 Feb 16:34
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f82afea0e76c300001f1">
#             The Daily What
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1688595185" data-title-time="1688595185">
#              05 Jul 22:13
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f819fea0e76c300001c9">
#             Get Rich Slowly
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1688490497" data-title-time="1688490497">
#              04 Jul 17:08
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f81dfea0e76c300001d7">
#             what if?
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1670373389" data-title-time="1670373389">
#              07 Dec 00:36
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f822fea0e76c300001e0">
#             The Old Reader: behind the scenes
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1639411908" data-title-time="1639411908">
#              13 Dec 16:11
#             </small>
#            </p>
#           </dd>
#          </dl>
#          <h3>
#           Inactive feeds
#          </h3>
#          <dl class="dead dl-horizontal">
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f822fea0e76c300001e0">
#             The Old Reader: behind the scenes
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1639411908" data-title-time="1639411908">
#              13 Dec 16:11
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f81dfea0e76c300001d7">
#             what if?
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1670373389" data-title-time="1670373389">
#              07 Dec 00:36
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f819fea0e76c300001c9">
#             Get Rich Slowly
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1688490497" data-title-time="1688490497">
#              04 Jul 17:08
#             </small>
#            </p>
#           </dd>
#           <dt>
#            <a class="label label-feed" data-pjax="" href="/feeds/65c3f82afea0e76c300001f1">
#             The Daily What
#            </a>
#           </dt>
#           <dd>
#            <p>
#             <small data-from-now="" data-time="1688595185" data-title-time="1688595185">
#              05 Jul 22:13
#             </small>
#            </p>
#           </dd>
#          </dl>
#          <h3>
#           Tips &amp; tricks
#           <i class="tips-refresh fa fa-refresh" data-idx="0">
#           </i>
#          </h3>
#          <div class="section">
#           Press '?' or 'h' to see the list of keyboard shortcuts.
#          </div>
#          <h3>
#           Our stuff
#          </h3>
#          <div class="section ourstuff">
#           <ul>
#            <li>
#             <a data-pjax="" href="/pages/tour">
#              Product Tour
#             </a>
#            </li>
#            <li>
#             <a href="http://blog.theoldreader.com/" rel="noopener noreferrer" target="_blank">
#              Blog
#             </a>
#            </li>
#            <li>
#             <a href="http://status.theoldreader.com/" rel="noopener noreferrer" target="_blank">
#              Server status
#             </a>
#            </li>
#            <li>
#             <a data-pjax="" href="/pages/apps">
#              Apps
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a data-pjax="" href="/pages/community">
#              Community resources
#             </a>
#            </li>
#            <li>
#             <a data-pjax="" href="/pages/tos">
#              Terms of Service
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a data-pjax="" href="/pages/privacy">
#              Privacy policy
#             </a>
#            </li>
#            <li>
#             <a data-pjax="" href="/sponsorships">
#              Sponsorships
#             </a>
#            </li>
#           </ul>
#           <a href="https://twitter.com/theoldreader" rel="noopener noreferrer" target="_blank">
#            <img height="14" src="//s.theoldreader.com/assets/ico-twitter-8162d5aeb1bed394f2dea033b43dabe5.png" width="14"/>
#           </a>
#           <a href="https://www.facebook.com/theoldreader" rel="noopener noreferrer" target="_blank">
#            <img height="14" src="//s.theoldreader.com/assets/ico-facebook-3ce8a7e5502a0e0e610f39ab127ec3b9.png" width="14"/>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="new-folder-modal-label" class="modal fade" id="new-folder-modal" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 id="new-folder-modal-label">
#        Create New Folder
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="alert alert-error hidden">
#        Folder name cannot be blank
#       </div>
#       <label>
#        Folder name
#       </label>
#       <input class="rename-textbox form-control" id="create-folder-name" placeholder="Folder name" type="text"/>
#       <input id="new-folder-subscription-id" type="hidden">
#        <input id="new-folder-url" type="hidden"/>
#       </input>
#      </div>
#      <div class="modal-footer">
#       <button aria-hidden="true" class="btn btn-default" data-dismiss="modal">
#        Cancel
#       </button>
#       <a class="btn btn-primary" href="#" id="create-folder-button">
#        Create folder
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="shortcuts-label" class="shortcuts modal fade" id="shortcuts" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-hidden="true" class="close" data-dismiss="modal" type="button">
#        ×
#       </button>
#       <h3 id="shortcuts-label">
#        Keyboard Shortcuts
#       </h3>
#      </div>
#      <div class="modal-body">
#       <div class="row">
#        <div class="col-md-4">
#         <p>
#          Navigate between pages
#         </p>
#         <table>
#          <tr>
#           <td>
#            shift-n, shift-j
#           </td>
#           <td>
#            next subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-p, shift-k
#           </td>
#           <td>
#            previous subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-x
#           </td>
#           <td>
#            collapse selected folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-o
#           </td>
#           <td>
#            open selected subscription or folder
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-c
#           </td>
#           <td>
#            collapse all folders
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift-e
#           </td>
#           <td>
#            expand all folders
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then h
#           </td>
#           <td>
#            go to home
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then a
#           </td>
#           <td>
#            go to all items
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then f
#           </td>
#           <td>
#            go to starred
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then l
#           </td>
#           <td>
#            go to liked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then s
#           </td>
#           <td>
#            go to shared
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then b
#           </td>
#           <td>
#            go to bookmarked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then t
#           </td>
#           <td>
#            go to trending
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then c
#           </td>
#           <td>
#            go to commented
#           </td>
#          </tr>
#          <tr>
#           <td>
#            g then p
#           </td>
#           <td>
#            go to following
#           </td>
#          </tr>
#         </table>
#         <p>
#          Other shortcuts
#         </p>
#         <table>
#          <tr>
#           <td>
#            r
#           </td>
#           <td>
#            refresh current page
#           </td>
#          </tr>
#          <tr>
#           <td>
#            /
#           </td>
#           <td>
#            focus the search field
#           </td>
#          </tr>
#          <tr>
#           <td>
#            a
#           </td>
#           <td>
#            add subscription
#           </td>
#          </tr>
#          <tr>
#           <td>
#            ? or h
#           </td>
#           <td>
#            show this window
#           </td>
#          </tr>
#          <tr>
#           <td>
#            d
#           </td>
#           <td>
#            dark mode
#           </td>
#          </tr>
#         </table>
#        </div>
#        <div class="col-md-4">
#         <p>
#          Shortcuts for posts
#         </p>
#         <table>
#          <tr>
#           <td>
#            space
#           </td>
#           <td>
#            scroll down
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift+space
#           </td>
#           <td>
#            scroll up
#           </td>
#          </tr>
#          <tr>
#           <td>
#            shift+a
#           </td>
#           <td>
#            mark all as read
#           </td>
#          </tr>
#          <tr>
#           <td>
#            j, n
#           </td>
#           <td>
#            next post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            k, p
#           </td>
#           <td>
#            previous post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            o, v
#           </td>
#           <td>
#            open post in a new tab
#           </td>
#          </tr>
#          <tr>
#           <td>
#            b
#           </td>
#           <td>
#            open post in a background tab*
#           </td>
#          </tr>
#          <tr>
#           <td>
#            x
#           </td>
#           <td>
#            toggle post (list view)
#           </td>
#          </tr>
#          <tr>
#           <td>
#            f
#           </td>
#           <td>
#            star a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            s
#           </td>
#           <td>
#            share a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            m
#           </td>
#           <td>
#            read/unread a post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            l
#           </td>
#           <td>
#            mark post as liked
#           </td>
#          </tr>
#          <tr>
#           <td>
#            c
#           </td>
#           <td>
#            scroll to comments and open the form
#           </td>
#          </tr>
#          <tr>
#           <td>
#            i
#           </td>
#           <td>
#            use Spritz to read post
#           </td>
#          </tr>
#          <tr>
#           <td>
#            1
#           </td>
#           <td>
#            switch to full view
#           </td>
#          </tr>
#          <tr>
#           <td>
#            2
#           </td>
#           <td>
#            switch to list view
#           </td>
#          </tr>
#         </table>
#         <small>
#          *Chrome, Safari, Opera only
#         </small>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    window.CONFIG = {
#     environment: "production",
#     assets_host: "//s.theoldreader.com",
#     I18n: {
#       defaultLocale: "en",
#       locale: "en",
#       fallbacks: true
#     }
#   }
#   </script>
#   <script src="//s.theoldreader.com/assets/application-401befeb476c4dda9b851e9a2447795e.js" type="text/javascript">
#   </script>
#   <script src="/ad.min.js">
#   </script>
#   <!-- <script type="text/javascript">
#   if(window.$) {
#     $(function() {
#       if(typeof canRunAdsOnTor === 'undefined') {
#         $('div.sidenav-cell .banner').remove();
#         $('#sidebar').removeClass('banner_user');
#       }
#     });
#   }
# </script> -->
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8488747604526930">
#   </script>
#   <script async="" defer="" src="//platform.instagram.com/en_US/embeds.js">
#   </script>
#   <script>
#    window.twttr = (function (d, s, id) {
#     var t, js, fjs = d.getElementsByTagName(s)[0];
#     if (d.getElementById(id)) return;
#     js = d.createElement(s); js.id = id;
#     js.src= "//platform.twitter.com/widgets.js";
#     fjs.parentNode.insertBefore(js, fjs);
#     return window.twttr || (t = { _e: [], ready: function (f) { t._e.push(f) } });
#   }(document, "script", "twitter-wjs"));
#   </script>
#   <div id="fb-root">
#   </div>
#   <script>
#    (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.5&appId=167033558637456";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
#   </script>
#  </body>
# </html>

# %%
verify = soup2.select_one('li.dropdown')
print(verify.text.strip())
# Out:
# Sujai Adithya
#
# Settings
# Manage Settings
# Manage Account
# Manage Subscriptions
# View Profile
#
# Help
# Product Tour
# Support
#
# Sign Out

# %% [markdown]
# Login has been successfully verified.
